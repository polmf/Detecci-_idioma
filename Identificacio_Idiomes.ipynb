# %% [markdown]
# # Pràctica 1
#
# **Membres del treball:**
# - Membre 1: Miquel Ropero Serrano
# - Membre 2: Pol Margarit Fisas

# %% [markdown]
# Carregar totes les dades

# %%
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/deu_trn.txt', 'r', encoding='utf-8') as f:
    deu_trn = f.read()

with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/deu_tst.txt', 'r', encoding='utf-8') as f:
    deu_tst = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/eng_trn.txt', 'r', encoding='utf-8') as f:
    eng_trn = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/eng_tst.txt', 'r', encoding='utf-8') as f:
    eng_tst = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/fra_trn.txt', 'r', encoding='utf-8') as f:
    fra_trn = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/fra_tst.txt', 'r', encoding='utf-8') as f:
    fra_tst = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/ita_trn.txt', 'r', encoding='utf-8') as f:
    ita_trn = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/ita_tst.txt', 'r', encoding='utf-8') as f:
    ita_tst = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/nld_trn.txt', 'r', encoding='utf-8') as f:
    nld_trn = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/nld_tst.txt', 'r', encoding='utf-8') as f:
    nld_tst = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/spa_trn.txt', 'r', encoding='utf-8') as f:
    spa_trn = f.read()
    
with open('C:/Users/Usuario/OneDrive/Escritorio/UPC/4rt Quadrimestre/PLH/Pràctica1/langId/spa_tst.txt', 'r', encoding='utf-8') as f:
    spa_tst = f.read()
    
"""with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/deu_trn.txt', 'r', encoding='utf-8') as f:
    deu_trn = f.read()

with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/deu_tst.txt', 'r', encoding='utf-8') as f:
    deu_tst = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/eng_trn.txt', 'r', encoding='utf-8') as f:
    eng_trn = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/eng_tst.txt', 'r', encoding='utf-8') as f:
    eng_tst = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/fra_trn.txt', 'r', encoding='utf-8') as f:
    fra_trn = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/fra_tst.txt', 'r', encoding='utf-8') as f:
    fra_tst = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/ita_trn.txt', 'r', encoding='utf-8') as f:
    ita_trn = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/ita_tst.txt', 'r', encoding='utf-8') as f:
    ita_tst = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/nld_trn.txt', 'r', encoding='utf-8') as f:
    nld_trn = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/nld_tst.txt', 'r', encoding='utf-8') as f:
    nld_tst = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/spa_trn.txt', 'r', encoding='utf-8') as f:
    spa_trn = f.read()
    
with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/spa_tst.txt', 'r', encoding='utf-8') as f:
    spa_tst = f.read()"""
# Out:
# "with open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/deu_trn.txt', 'r', encoding='utf-8') as f:\n    deu_trn = f.read()\n\nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/deu_tst.txt', 'r', encoding='utf-8') as f:\n    deu_tst = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/eng_trn.txt', 'r', encoding='utf-8') as f:\n    eng_trn = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/eng_tst.txt', 'r', encoding='utf-8') as f:\n    eng_tst = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/fra_trn.txt', 'r', encoding='utf-8') as f:\n    fra_trn = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/fra_tst.txt', 'r', encoding='utf-8') as f:\n    fra_tst = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/ita_trn.txt', 'r', encoding='utf-8') as f:\n    ita_trn = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/ita_tst.txt', 'r', encoding='utf-8') as f:\n    ita_tst = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/nld_trn.txt', 'r', encoding='utf-8') as f:\n    nld_trn = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/nld_tst.txt', 'r', encoding='utf-8') as f:\n    nld_tst = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/spa_trn.txt', 'r', encoding='utf-8') as f:\n    spa_trn = f.read()\n    \nwith open('C:/Users/USER/Desktop/UPC/quartquatri/PLH/practica1/spa_tst.txt', 'r', encoding='utf-8') as f:\n    spa_tst = f.read()"

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Eliminació de digits

# %%
import re

sense_digits_deu_trn = re.sub(r'\d', '', deu_trn)
sense_digits_deu_tst = re.sub(r'\d', '', deu_tst)

sense_digits_eng_trn = re.sub(r'\d', '', eng_trn)
sense_digits_eng_tst = re.sub(r'\d', '', eng_tst)

sense_digits_fra_trn = re.sub(r'\d', '', fra_trn)
sense_digits_fra_tst = re.sub(r'\d', '', fra_tst)

sense_digits_ita_trn = re.sub(r'\d', '', ita_trn)
sense_digits_ita_tst = re.sub(r'\d', '', ita_tst)

sense_digits_nld_trn = re.sub(r'\d', '', nld_trn)
sense_digits_nld_tst = re.sub(r'\d', '', nld_tst)

sense_digits_spa_trn = re.sub(r'\d', '', spa_trn)
sense_digits_spa_tst = re.sub(r'\d', '', spa_tst)

# %% [markdown]
# ### Convertir text en miniscula

# %%
minuscules_deu_trn = sense_digits_deu_trn.lower()
minuscules_deu_tst = sense_digits_deu_tst.lower()

minuscules_eng_trn = sense_digits_eng_trn.lower()
minuscules_eng_tst = sense_digits_eng_tst.lower()

minuscules_fra_trn = sense_digits_fra_trn.lower()
minuscules_fra_tst = sense_digits_fra_tst.lower()

minuscules_ita_trn = sense_digits_ita_trn.lower()
minuscules_ita_tst = sense_digits_ita_tst.lower()

minuscules_nld_trn = sense_digits_nld_trn.lower()
minuscules_nld_tst = sense_digits_nld_tst.lower()

minuscules_spa_trn = sense_digits_spa_trn.lower()
minuscules_spa_tst = sense_digits_spa_tst.lower()

# %% [markdown]
# ### Substitució d'espais continus

# %%
un_espai_deu_trn = re.sub(r'\s+', ' ', minuscules_deu_trn)
un_espai_deu_tst = re.sub(r'\s+', ' ', minuscules_deu_tst)

un_espai_eng_trn = re.sub(r'\s+', ' ', minuscules_eng_trn)
un_espai_eng_tst = re.sub(r'\s+', ' ', minuscules_eng_tst)

un_espai_fra_trn = re.sub(r'\s+', ' ', minuscules_fra_trn)
un_espai_fra_tst = re.sub(r'\s+', ' ', minuscules_fra_tst)

un_espai_ita_trn = re.sub(r'\s+', ' ', minuscules_ita_trn)
un_espai_ita_tst = re.sub(r'\s+', ' ', minuscules_ita_tst)

un_espai_nld_trn = re.sub(r'\s+', ' ', minuscules_nld_trn)
un_espai_nld_tst = re.sub(r'\s+', ' ', minuscules_nld_tst)

un_espai_spa_trn = re.sub(r'\s+', ' ', minuscules_spa_trn)
un_espai_spa_tst = re.sub(r'\s+', ' ', minuscules_spa_tst)

# %% [markdown]
# ### Cocatenar frases amb un espai doble

# %%
import nltk
from nltk.tokenize import sent_tokenize

# %%
# Divideix el text en frases
frases = sent_tokenize(un_espai_deu_trn, language='german')
text_processat_deu_trn = "  ".join(frases)
frases = sent_tokenize(un_espai_deu_tst, language='german')
text_processat_deu_tst = "  ".join(frases)

frases = sent_tokenize(un_espai_eng_trn)
text_processat_eng_trn = "  ".join(frases)
frases = sent_tokenize(un_espai_eng_tst)
text_processat_eng_tst = "  ".join(frases)

frases = sent_tokenize(un_espai_fra_trn, language='french')
text_processat_fra_trn = "  ".join(frases)
frases = sent_tokenize(un_espai_fra_tst, language='french')
text_processat_fra_tst = "  ".join(frases)

frases = sent_tokenize(un_espai_ita_trn, language='italian')
text_processat_ita_trn = "  ".join(frases)
frases = sent_tokenize(un_espai_ita_tst, language='italian')
text_processat_ita_tst = "  ".join(frases)

frases = sent_tokenize(un_espai_nld_trn, language='dutch')
text_processat_nld_trn = "  ".join(frases)
frases = sent_tokenize(un_espai_nld_tst, language='dutch')
text_processat_nld_tst = "  ".join(frases)

frases = sent_tokenize(un_espai_spa_trn, language='spanish')
text_processat_spa_trn = "  ".join(frases)
frases = sent_tokenize(un_espai_spa_tst, language='spanish')
text_processat_spa_tst = "  ".join(frases)

# %% [markdown]
# ## Utilitzem trigrams de caràcters com a model del llenguatge

# %% [markdown]
# <span style="color:lightgreen"> Només generem trigrames en els corpus d'entrenament per completar el preprocessament de les dades, eliminant posteriorment aquells trigrames que apareixen menys de 5 vegades en els conjunts d'entrenament. Més endavant, quan calculem la probabilitat dels trigrames pels corpus de prova, necessitarem tot el text per poder dividir-lo en frases i avaluar el model basant-nos en les prediccions fetes sobre l'idioma per a cada frase.</span>

# %%
from nltk.collocations import TrigramCollocationFinder

trigrames_deu_trn = TrigramCollocationFinder.from_words(text_processat_deu_trn)

trigrames_eng_trn = TrigramCollocationFinder.from_words(text_processat_eng_trn)

trigrames_fra_trn = TrigramCollocationFinder.from_words(text_processat_fra_trn)

trigrames_ita_trn = TrigramCollocationFinder.from_words(text_processat_ita_trn)
 
trigrames_nld_trn = TrigramCollocationFinder.from_words(text_processat_nld_trn)

trigrames_spa_trn = TrigramCollocationFinder.from_words(text_processat_spa_trn)

# %%
print("Trigrames abans del filtre:")
for trigram, freq in trigrames_spa_trn.ngram_fd.items():
    if freq <5:
        print(trigram, freq)
# Out:
# Trigrames abans del filtre:
# ('(', 'e', 'v') 1
# ('b', 'ú', '”') 1
# ('ú', '”', ' ') 1
# ('w', 'o', 'u') 1
# ('w', 'e', 'y') 2
# ('f', ' ', 'v') 2
# ('ñ', 'a', 't') 2
# ('r', 'p', 'f') 3
# ('p', 'f', '.') 2
# ('b', 'e', 'v') 2
# ('r', 'l', 'y') 4
# ('e', 'f', ')') 2
# ('k', 'e', 'm') 3
# ('á', 'n', 'k') 4
# ('y', 'e', 'p') 2
# ('z', 'a', '!') 2
# ('h', 'a', 'o') 4
# ('a', 'c', 'd') 3
# ('e', 'a', 'h') 3
# ('e', 'u', 'b') 2
# ('r', 'o', '@') 1
# ('o', '@', 'a') 1
# ('@', 'a', 'l') 2
# ('ü', 'e', ',') 2
# ('v', 'í', 'k') 1
# ('í', 'k', 't') 1
# ('k', 't', 'o') 4
# ('-', ' ', '"') 4
# ('f', 'o', '”') 2
# ('p', 's', 't') 4
# ('j', 'e', '?') 3
# ('(', 'd', 'p') 2
# ('d', 'p', 'z') 1
# ('p', 'z', ')') 1
# ('z', ')', ' ') 4
# (')', ' ', '"') 1
# ('j', 'a', "'") 3
# ('a', 'p', 'j') 3
# ('p', 'j', 'p') 3
# ('j', 'p', 'u') 3
# ('u', 's', '>') 3
# ('s', '>', ' ') 3
# ('>', ' ', 'g') 1
# ('"', 'é', 'r') 1
# ('v', 'o', 'e') 3
# ('l', ' ', '…') 2
# ('s', 'é', 'g') 1
# ('é', 'g', 'o') 1
# ('o', 'l', 'è') 1
# ('l', 'è', 'l') 1
# ('è', 'l', 'e') 1
# ('p', 'd', ':') 1
# ('“', 'j', 'o') 2
# ("'", 'd', 'a') 4
# ('t', 'm', 'p') 1
# ('m', 'p', 'f') 3
# ('p', 'f', 's') 2
# ('f', 's', '.') 3
# ('u', 'z', 'z') 2
# ('e', 'x', 'n') 2
# ('x', 'n', 'o') 2
# ('s', 'o', 'q') 1
# ('«', 'h', 'o') 1
# ('e', 'd', '»') 1
# ('d', '»', '.') 4
# ('m', 'c', ')') 2
# ('c', ')', '.') 4
# ('n', 'ó', '”') 2
# ('ó', '”', '.') 4
# ('e', ':', 's') 1
# (':', 's', 'i') 1
# ('e', 'u', 'q') 3
# ('u', 'é', 'n') 2
# ('-', 'c', 'é') 2
# ('i', 'c', '"') 3
# ('c', '"', '.') 2
# ('f', 'l', 'p') 3
# ('o', 't', '.') 4
# ('u', 't', 'n') 2
# ('i', 'k', '.') 2
# (' ', '‘', 'g') 4
# ('‘', 'g', 'l') 1
# ('i', 'a', '’') 1
# ('a', '’', ',') 2
# ('(', 'u', 'c') 3
# ('u', 'c', 'm') 1
# ('c', 'm', ')') 2
# ('(', 'g', 'm') 4
# ('á', ' ', 'k') 2
# ('a', 'd', 'c') 2
# ('a', 'v', '.') 1
# ('i', 'e', '”') 2
# ('k', 'y', 'u') 1
# ('ñ', 'i', 'o') 4
# ('e', 'z', 'b') 3
# ('z', 'b', 'o') 4
# ('a', 'v', 'ó') 4
# ('e', 'a', '”') 1
# ('a', '”', '”') 1
# ('”', '”', '.') 1
# (' ', '%', ')') 2
# ('(', 'e', '.') 1
# ('(', 'z', 'a') 3
# ('u', 'l', 'á') 4
# ('i', 'r', 'w') 3
# ('n', 'b', ' ') 2
# ('z', 'o', 'u') 4
# ('(', 'o', 'r') 3
# ('k', 'o', 'h') 4
# ('(', 'b', 'r') 2
# ('z', ' ', 'ó') 1
# ('m', 'v', 'p') 2
# ('v', 'p', ' ') 2
# ('c', 'd', 'u') 3
# (' ', 'ú', 'r') 3
# ('ú', 'r', 's') 3
# ('w', 'n', 'l') 3
# (' ', '¡', 'd') 4
# ('g', 'á', ' ') 4
# ('o', 'r', '!') 4
# ('ú', 'n', "'") 2
# ('d', 'á', 'm') 3
# ('r', 'j', 'l') 1
# ('j', 'l', ')') 1
# (' ', 's', '-') 4
# ('e', 'm', ')') 3
# ('m', ')', '.') 3
# ('t', 'v', 'v') 2
# ('v', 'v', ',') 1
# ('v', 'v', ' ') 1
# ("'", 'g', 'ü') 1
# ('g', 'ü', 'r') 3
# ('i', 'v', 'f') 2
# ('v', 'f', ',') 1
# ('h', 'i', '-') 1
# ('i', '-', 'g') 2
# ('-', 'g', 'u') 2
# ('g', 'a', 'w') 2
# ('w', 'a', '-') 1
# ('a', '-', 'k') 1
# ('e', 'e', 'x') 2
# ('l', 'p', 'í') 1
# ('p', 'í', 'z') 1
# ('í', 'z', 'a') 3
# ('n', 'm', 'é') 1
# ('í', 'a', ';') 3
# ('p', 'c', 's') 3
# ('u', 'x', '…') 2
# ('x', '…', ' ') 1
# ('…', ' ', 's') 4
# ('(', 'r', 'o') 3
# ('s', 's', 'h') 2
# ('i', 't', 'b') 4
# ('t', 'b', 'e') 1
# ('f', 'e', 'z') 2
# ('u', 'r', 'z') 3
# ('k', 'n', 'i') 4
# (' ', ')', 'i') 1
# (')', 'i', 'n') 1
# (' ', ')', 'd') 1
# (')', 'd', 'i') 1
# ('n', 'á', 's') 4
# ('s', 'e', ';') 1
# ("'", 'o', 'n') 1
# ('k', 'h', 'i') 1
# ('p', 'o', ':') 3
# (':', ' ', '’') 1
# ('(', 'v', ')') 1
# ('v', ')', ',') 2
# ('p', 'é', 'c') 3
# ('é', 'c', 's') 1
# ('z', ' ', "'") 2
# ('ó', ' ', '%') 3
# ('o', '.', 'e') 4
# ('v', 's', '.') 4
# ('t', 'u', 'z') 3
# ('u', 'z', 'o') 3
# ('f', 'l', 'á') 1
# ('o', 'z', 'm') 3
# ('(', 'e', 'p') 1
# ('i', 'i', 'z') 1
# ('z', 'e', 'k') 3
# ('e', 'k', 'e') 4
# ('e', 'i', 'i') 2
# ('h', 'n', 'o') 4
# ('m', 's', 'p') 1
# ('j', ' ', 'q') 2
# ('a', 'k', '"') 4
# (' ', 'g', 'd') 3
# ('g', 'd', 'f') 3
# (' ', '‘', 'l') 4
# ('‘', 'l', 'a') 2
# ('r', 'a', 'ó') 2
# ('a', 'ó', 'n') 2
# ('i', 'n', '¿') 1
# ('n', '¿', '.') 1
# ('¿', '.', ' ') 1
# ('o', 'g', 'h') 3
# ('g', 'h', ':') 2
# ('c', ' ', 'i') 3
# ('c', 't', 's') 4
# (' ', 'v', '-') 2
# ('v', '-', 's') 1
# ('«', 't', 'r') 1
# ('u', 'm', 'f') 2
# ('m', 'f', 'á') 1
# ('á', 'l', 'n') 1
# ('l', 'n', 'a') 4
# ('y', 'a', '»') 1
# ('»', ' ', 'n') 2
# ('t', 'u', 'f') 2
# (' ', 'k', 'b') 2
# ('k', 'b', 'w') 1
# ('b', 'w', ' ') 1
# ('m', 'í', 'f') 4
# ('"', 'o', 'c') 4
# ('n', 'é', 'p') 1
# ("'", ' ', 'á') 1
# ('a', 'z', 'q') 1
# ('t', 'i', ':') 2
# ('(', 'i', 'g') 2
# ('v', 'a', '»') 2
# ('e', 'a', ':') 4
# ('l', 'g', ' ') 4
# ('h', 'd', 'm') 4
# ('o', 'b', '.') 3
# ('(', ':', '.') 2
# (':', '.', ')') 3
# (' ', "'", 'q') 3
# ("'", 'q', 'u') 2
# ('é', 'b', 'o') 2
# (' ', 'l', 'j') 1
# ('l', 'j', 'u') 1
# ('z', 'á', 'b') 3
# ('c', 'y', 'b') 3
# ('r', '-', 's') 3
# ('s', 'c', '-') 1
# ('c', '-', 'h') 1
# ('-', 'h', 'x') 1
# ('h', 'x', 'v') 2
# ('m', ' ', 'u') 3
# (' ', 'h', 'x') 2
# ('h', 'x', ' ') 2
# ('x', 'v', '.') 1
# ('f', 'a', ')') 3
# ('l', 'c', 'k') 2
# ('%', ' ', 'o') 4
# ('s', '$', '.') 3
# ('f', ' ', 'i') 2
# ('b', 'i', 'ñ') 2
# ('"', 'm', 'é') 4
# ('r', 'y', '”') 1
# ('y', '”', ' ') 2
# ('b', 'ú', 'e') 1
# ('u', 'z', 'u') 4
# ('z', 'u', ' ') 4
# ('d', 'á', 't') 1
# ('c', 'í', 't') 1
# (' ', '@', 'u') 1
# ('@', 'u', 'e') 1
# ('+', ' ', 't') 3
# ('s', ' ', '@') 4
# ('@', 'f', 'a') 2
# ('f', 'a', 'a') 4
# ('a', 'a', 'k') 4
# ('é', 'm', 'e') 1
# ('i', 'd', 'h') 3
# ('d', 'h', ' ') 4
# ('o', 'x', 'y') 3
# ('a', 'a', 'm') 3
# ('n', 'c', 'f') 4
# ('c', 'f', 'o') 4
# ('ú', ' ', 'a') 4
# (' ', 'w', 's') 1
# ('w', 's', 'b') 1
# ('b', ' ', 'h') 4
# ('o', 'f', 'g') 1
# ('f', 'g', 'r') 1
# ('u', 's', 'm') 4
# (' ', 'l', 't') 3
# ('l', 't', 'd') 4
# ('t', 'd', ' ') 2
# ('h', 'e', 'j') 2
# ('n', 'g', 'm') 1
# ('u', 'á', 't') 3
# ('s', 'c', 'j') 1
# ('c', 'j', 'n') 1
# ('j', 'n', ' ') 1
# ("'", 'n', 'a') 2
# ('w', 'k', 'i') 4
# ('r', '.', ':') 1
# ('y', 'r', 't') 1
# ('o', 'l', 'q') 3
# ('f', 'e', '"') 2
# ('n', 'l', ' ') 3
# ('c', 'n', 'e') 4
# ('.', '%', '.') 4
# ('l', 'í', 'z') 1
# ('h', 'o', "'") 4
# ('q', ' ', 'l') 1
# ('a', ')', '?') 1
# (')', '?', ' ') 4
# ('a', ')', ':') 2
# ('a', ' ', '°') 3
# ('°', ' ', 'y') 2
# ('y', ' ', '°') 2
# ("'", 'a', 'v') 1
# ('a', 'v', 'v') 1
# ('v', 'v', 'e') 1
# ('b', 'y', '.') 3
# (' ', 'e', 'o') 2
# ('ú', 'n', ':') 3
# ('e', 'p', '-') 3
# ('p', '-', ' ') 2
# ('-', ' ', ':') 4
# ('t', ' ', '¿') 1
# ('¿', 'a', 'v') 2
# ("'", ' ', 'b') 4
# ('z', 'h', 'i') 1
# ('t', 'á', 'f') 4
# ('z', 'o', 'q') 3
# (' ', 'd', 'z') 4
# ('d', 'z', 'i') 3
# ('z', 'i', 'b') 2
# (' ', 'm', '/') 1
# ('m', '/', 'd') 1
# ('/', 'd', 'í') 1
# ('o', 'y', "'") 3
# ('y', "'", '.') 2
# ('g', ' ', ':') 1
# ('a', 'h', '.') 4
# ('c', 'n', 'u') 4
# ('s', 'e', '…') 2
# ('@', 'a', 'i') 1
# ('+', ' ', 'b') 1
# ('m', 'a', '!') 2
# ('o', 'u', 'k') 1
# ('a', ',', '"') 3
# (',', '"', ' ') 4
# (' ', '—', 'y') 1
# ('—', 'y', ' ') 1
# ('i', 'a', '—') 3
# ('a', '—', ',') 2
# ('“', 'a', 'b') 2
# ('n', 'k', 'y') 1
# ('h', 'á', '.') 2
# (' ', 'l', 'm') 4
# ('“', 'h', 'u') 4
# ('r', ' ', ':') 3
# ('l', 's', '”') 2
# ('u', ' ', '&') 1
# ('&', ' ', 'b') 2
# ('x', 'i', ',') 3
# ('…', ' ', 'u') 4
# ('o', 'a', ')') 3
# ('c', 'e', 'á') 2
# ('«', 'l', 'o') 3
# ('l', 't', '»') 1
# ('t', '»', ',') 2
# ('n', 'i', 'è') 1
# ('i', 'è', 'r') 2
# ('è', 'r', 'e') 3
# (' ', 'f', 'h') 3
# ('f', 'h', 'f') 1
# ('h', 'f', 'a') 1
# ('l', 'h', 'e') 4
# ('k', '.', '.') 1
# ('h', '.', '-') 2
# ('g', 'e', "'") 3
# ('o', 'g', 'n') 4
# ('o', 'a', 'o') 2
# ('h', 'o', 'z') 2
# ('h', 'í', 't') 2
# ('“', 'm', 'é') 1
# ('r', ' ', '‘') 2
# ('‘', 'b', 'u') 2
# ('h', 'a', '’') 2
# ('p', 'r', '.') 1
# ('d', 'a', 'o') 3
# (' ', 'r', 'c') 4
# ('r', 'c', 'd') 2
# ('b', 'í', 'q') 2
# ('é', 'r', 'y') 2
# ('u', 'l', 'k') 4
# ('k', 'e', 'ó') 1
# ('h', 'm', 'i') 4
# ('i', 'd', 't') 4
# ('o', ',', 'e') 4
# (',', 'e', 'l') 4
# ('o', 'e', 'x') 3
# ('n', 'j', 'é') 1
# ('a', 'h', 't') 1
# ('ñ', 'a', 'z') 3
# ('a', '.', 'r') 2
# ('.', 'r', '.') 2
# ('r', '.', 'c') 2
# ('c', '.', 'e') 1
# ('.', 'e', '”') 1
# ('ú', 'n', 'm') 3
# ('y', 'e', 't') 2
# ('h', 'a', ')') 4
# (' ', 'é', 'v') 1
# ('é', 'v', 'o') 3
# ('b', 'r', 'é') 3
# ('k', 'u', 'a') 3
# ('k', 'l', 'c') 2
# ('a', 'c', 'm') 3
# ('s', '-', 'c') 3
# ('o', 'l', '?') 1
# ('m', 's', 'o') 2
# ('w', ' ', 'p') 3
# ('e', '"', '/') 1
# ('"', '/', '"') 1
# ('/', '"', 'n') 1
# ('y', 't', 'á') 1
# ('c', 'i', 'à') 2
# ('i', 'à', '"') 1
# ('à', '"', ',') 1
# ('l', 'k', 'o') 4
# (' ', 'n', '°') 3
# ('n', '°', ' ') 3
# ('"', 'j', 'e') 1
# ('/', 'h', ' ') 2
# ('/', 'h', '.') 4
# ('–', 'r', 'e') 4
# ('c', 'ó', '–') 1
# ('–', ' ', 'b') 1
# ('a', 'n', 'ç') 4
# ('n', 'ç', 'o') 4
# ('ç', 'o', 'i') 3
# ('z', 'i', 'm') 4
# ('n', 'a', '…') 4
# ('.', ' ', '·') 1
# (' ', '·', ' ') 4
# ('·', ' ', 'n') 1
# ('l', 's', '-') 3
# ('s', '-', 'f') 2
# ('-', 'f', 'l') 3
# ('í', ' ', 'j') 4
# ('t', 'b', 'u') 2
# ('k', 'a', 'a') 2
# ('a', 'a', 'i') 1
# ('m', 'b', 'í') 2
# ('p', 'i', ',') 4
# ('w', 'i', 'i') 3
# (' ', 'n', 'd') 3
# ('r', '-', 'c') 1
# ('d', 'w', 'e') 1
# ('d', 'i', 'i') 3
# ('i', 'i', 'a') 2
# ('m', 'i', '”') 1
# ('i', '”', ',') 2
# ('a', 's', '/') 2
# ('s', '/', 'm') 4
# ('/', 'm', 'e') 3
# ('"', 'o', 'j') 2
# ('n', 'ú', '.') 2
# ('r', 't', 'w') 1
# ('t', 'w', 'ä') 1
# ('w', 'ä', 'n') 1
# ('ä', 'n', 'g') 1
# ('s', '"', 'a') 1
# ('p', 'e', '?') 1
# ('r', ' ', 'í') 2
# ('e', 'r', ';') 3
# (';', ' ', '¿') 1
# ('s', '»', ' ') 4
# ('»', ' ', 'm') 1
# ('n', 'e', '?') 2
# ('a', 'e', 'x') 1
# ('s', 'a', '/') 1
# ('a', '/', 'c') 3
# ('/', 'c', 'a') 2
# ('¿', 'a', 's') 2
# ('l', 't', 'í') 2
# ('r', 'i', "'") 1
# ('o', 'n', 'b') 2
# ('d', 's', '”') 2
# ('t', 'i', 'w') 1
# ('i', 'w', 'i') 1
# ('w', 'i', ' ') 2
# ('-', 'a', 'z') 3
# ('i', ' ', '%') 3
# ("'", 'p', 'u') 3
# ('g', 'i', 'y') 1
# ('i', 'y', ' ') 2
# ('f', 'e', 'u') 4
# ('s', 'k', 'b') 1
# ('k', 'b', 'a') 2
# ('p', 'í', 's') 3
# ('r', 'g', 'r') 4
# ('ñ', 'i', 's') 4
# ('s', 'm', 'ó') 3
# ('u', 'l', 'f') 4
# (' ', '«', 'b') 2
# ('«', 'b', 'l') 1
# ('z', 'a', '»') 1
# ('»', ' ', 'q') 3
# ('o', 'r', '»') 1
# ('r', '»', ',') 2
# ('b', 'b', ':') 1
# ('ú', 'l', 'i') 3
# (' ', 'f', ' ') 3
# ('p', 'o', ')') 3
# ('w', ' ', '(') 2
# ('t', 'i', ')') 1
# ('h', 't', "'") 3
# ('t', "'", ',') 3
# ("'", 'l', 'l') 2
# ('t', 'i', "'") 1
# ('i', "'", ',') 4
# ("'", 's', 'c') 1
# ('p', 'e', "'") 4
# ("'", 'h', 'e') 4
# ("'", 'i', ' ') 1
# ('i', 't', "'") 1
# ('y', 'd', '(') 1
# ('d', '(', 'o') 1
# ('l', 'p', ',') 2
# (' ', "'", '.') 4
# ('e', 'x', 'g') 3
# ('x', 'g', 'o') 3
# ('v', ' ', 't') 4
# ('s', 'e', '-') 4
# ('$', ',', ',') 3
# (',', ',', '.') 1
# ('u', 's', 'é') 3
# ('t', 'á', 'z') 3
# ('g', 'r', ',') 1
# ('h', 'u', 'z') 2
# ('e', 'h', 'm') 4
# (' ', 'z', 'd') 1
# ('z', 'd', 'f') 1
# ('d', 'f', ',') 1
# ('a', 't', ')') 4
# ('t', 'z', 'o') 2
# ('"', 'c', 'á') 2
# ('s', "'", "'") 2
# ("'", "'", ' ') 3
# ('g', 'e', 'ó') 4
# ('n', 'c', 'y') 4
# ('y', 'i', 's') 4
# ('v', 'o', 'u') 4
# ('r', 'g', 'y') 4
# ('g', 'y', ' ') 4
# (' ', 'm', 'r') 3
# ('m', 'r', 'p') 2
# ('t', 'n', 'o') 3
# ('n', 'o', 'y') 1
# ('y', 'o', 'b') 1
# ('g', 't', 'a') 1
# ('m', 'a', 'o') 4
# (' ', 'ó', 'm') 4
# ('t', 'e', 'á') 1
# (' ', '"', 'ú') 4
# ('"', 'ú', 'n') 3
# ('o', 'y', 'l') 4
# ('l', 'e', ';') 4
# ('x', '/', 'r') 2
# ('/', 'r', 't') 1
# ('t', 'l', '/') 1
# ('l', '/', 'm') 2
# ('/', 'm', 'r') 2
# ('m', 'r', 'g') 2
# ('r', 'g', '/') 3
# ('g', '/', 't') 1
# ('/', 't', 'i') 1
# ('d', 'e', '?') 3
# ('(', 'm', '.') 2
# ('m', '.', ')') 4
# ('m', 's', '"') 2
# ('l', 'i', 'é') 2
# ('i', 'é', 'v') 1
# ('é', 'v', 'a') 2
# ('e', 'y', ':') 2
# ('d', ' ', '“') 1
# ('s', 'c', '.') 3
# ("'", 'w', 'a') 2
# ('(', 'e', 'r') 3
# ('y', 'c', 'k') 1
# ('l', 'á', '-') 1
# ('á', '-', ' ') 1
# ('x', 'x', '?') 1
# ('x', '?', ' ') 2
# ('l', 'd', 'ú') 1
# ('d', 'ú', 'a') 1
# ('k', 'e', 'f') 4
# ('z', 'e', 'c') 1
# (' ', 'o', '’') 3
# ('o', '’', 'b') 1
# ('’', 'b', 'r') 1
# ('n', 'e', '’') 3
# ('e', '’', 's') 4
# ('j', ' ', 'y') 2
# ('t', 'é', "'") 1
# ('é', "'", ',') 1
# ('k', 'u', 'i') 1
# ('i', 'd', ')') 2
# ('m', 'c', 'f') 2
# ('c', 'f', 'l') 2
# ('d', "'", 's') 3
# ('"', 'j', 'ó') 1
# ('p', 'c', 'c') 4
# ('c', 'o', '»') 3
# ('»', ' ', 'f') 1
# ('n', 'a', 'ñ') 1
# ('a', 'ñ', 'ú') 1
# ('ñ', 'ú', ' ') 1
# ('é', ' ', '"') 4
# ('u', 'y', ')') 1
# ('s', 'g', 'e') 3
# (' ', 'j', 'j') 4
# ('j', 'j', ' ') 3
# ('j', ' ', 'p') 3
# (' ', '%', ';') 2
# ('%', ';', ' ') 2
# ('p', 'ó', 'r') 2
# ('ó', 'r', 't') 3
# ('ó', 't', 'o') 2
# ('“', 's', 't') 1
# ('r', 's', '”') 3
# ('á', 'n', 'o') 3
# ('f', 'e', 'a') 4
# ('o', 'g', 'ó') 4
# ('"', 'i', 'd') 3
# ('y', 'u', 'l') 1
# ('h', 'í', 'd') 4
# ('í', 'd', 'r') 4
# ('c', 't', 'c') 2
# (' ', 'í', 'c') 2
# ('p', ',', '"') 1
# (',', '"', 'c') 1
# ('m', 'i', 'á') 3
# ('ñ', 'e', 't') 4
# ('v', ' ', ':') 1
# ('i', 'u', 't') 2
# ('"', 'b', 'l') 4
# ('o', 'o', 'w') 2
# ('o', 'w', 'o') 1
# ('g', 'é', 'm') 4
# ('d', 'u', ')') 2
# ('e', 'i', 'w') 3
# ('i', 'w', 'e') 3
# ('o', 'y', ')') 3
# ('f', 'é', 's') 4
# ('d', 'e', 'x') 3
# ('s', '-', 'o') 3
# ('-', 'o', 'f') 2
# ('i', 'e', 'i') 2
# ('r', 't', 'b') 1
# ('t', 'b', 'r') 1
# ('e', 'f', 't') 1
# ('s', 'r', 't') 1
# (' ', 'm', '"') 1
# ('m', '"', ',') 4
# ('ñ', 'a', ':') 4
# ('r', 'c', 'k') 2
# ('“', 'f', 'o') 2
# ('p', 'e', 'e') 4
# ('o', 'y', ':') 1
# ('i', 'ó', '"') 4
# ('ó', '"', ' ') 4
# ('l', 'é', ',') 3
# ('p', 'h', ')') 3
# ('l', 'f', ',') 3
# ("'", 'm', 'u') 3
# ('i', 'r', 'q') 2
# ('e', ' ', '¡') 4
# ('¡', 'e', 's') 3
# ('a', 'l', '!') 4
# ('l', '!', ' ') 4
# ('í', 'a', 'l') 1
# ('p', 'a', 'x') 1
# ('m', 's', ')') 4
# ('á', 's', 'k') 1
# ('e', 't', "'") 3
# ('f', 'o', 'p') 1
# ('d', 'j', ',') 1
# ('"', '¡', 'q') 4
# ('(', ' ', 'y') 3
# ('r', '.', ',') 3
# ('f', 'n', ' ') 1
# ('f', 'é', 'm') 1
# ('u', 'd', 'y') 3
# ('f', 'f', 't') 1
# ('a', 'í', 't') 1
# ('í', 't', 'o') 3
# ('l', "'", 'h') 1
# ("'", 'h', 'o') 4
# ('a', 'ñ', 'u') 4
# ('e', 'i', 'o') 1
# ('c', 'a', 'k') 1
# ('s', ' ', '€') 4
# ('€', ' ', 'p') 3
# ('d', 'é', 'r') 3
# ('é', 'r', 'n') 1
# ('€', ' ', 'o') 1
# ('y', 'e', 'w') 2
# ('n', 't', '-') 3
# ('t', '-', 'e') 3
# ('-', 'e', 't') 1
# ('ñ', 'ó', ',') 1
# ('n', 'i', "'") 3
# ('-', 'm', '"') 2
# ('e', ' ', 'ª') 1
# ('ª', ' ', 'a') 1
# ('u', 'o', 'm') 3
# ('c', 'a', 'ó') 4
# ('a', 'ó', 't') 4
# ('g', 'á', 'f') 1
# ('h', 'o', ':') 2
# ('a', 'g', ',') 2
# ('“', 'u', 's') 1
# ('«', 'e', 'x') 1
# ('a', 'd', '»') 4
# ('c', 'd', 's') 4
# ('d', 's', '-') 1
# ('s', '-', 'p') 3
# ('-', 'p', 'p') 2
# ('p', 's', 'd') 3
# ('(', 't', 's') 4
# ('t', 's', 'e') 4
# ('l', 'd', 'á') 2
# ('s', 'i', 'j') 4
# ('i', 'j', 's') 1
# ('j', 's', ',') 2
# ('i', 'c', '”') 1
# ('c', '”', ' ') 1
# ('n', 'd', '”') 2
# ('c', ' ', 'é') 1
# ('p', 's', 'ó') 1
# ('r', 'c', 't') 2
# ('y', 's', '.') 2
# ('e', 'z', ':') 1
# (' ', '—', 'q') 2
# ('—', 'q', 'u') 2
# ('n', 'o', '—') 1
# ('—', ' ', '"') 2
# ('.', '.', ',') 4
# ('(', 'e', 'c') 3
# ('n', 'o', 'e') 4
# ('b', 'í', 'c') 2
# ('(', 'a', '.') 1
# ('p', 'o', 'é') 4
# ('o', 'é', 't') 4
# ('a', 'g', 'á') 3
# ('v', 'i', '"') 1
# ('¡', 'p', 'u') 3
# ('“', 'g', 'r') 4
# ('e', 's', '/') 2
# ('s', '/', 'g') 2
# ('/', 'g', 'r') 2
# ('a', 's', '“') 1
# ('s', '“', '.') 1
# ('“', '.', ' ') 1
# ('u', 't', 'y') 2
# ('t', 'á', '”') 2
# ('á', '”', ',') 3
# ('é', 'l', ')') 3
# ('k', 's', 'y') 3
# ('"', 'n', '"') 2
# ('y', 'u', 'm') 3
# ('h', 'á', 'l') 1
# ('s', 's', 'y') 1
# ('n', 'u', 'z') 1
# ('l', ' ', 'º') 1
# ('º', ' ', 'a') 1
# ('s', 'u', '.') 1
# ('e', ',', 't') 1
# (',', 't', 'o') 2
# ('a', ',', 't') 1
# (',', 't', 'e') 1
# (' ', 'u', 'x') 3
# ('m', 'p', 'c') 1
# ('r', 'h', 'é') 3
# ('g', 'o', 'k') 2
# ('n', ' ', '…') 4
# ('y', 'o', 'g') 3
# ('/', ' ', 'm') 2
# ('p', 'd', ')') 3
# ('e', 'z', 'h') 3
# ('z', 'h', 'u') 3
# ('n', 'g', 'á') 4
# ('g', 'l', 'ú') 3
# ('l', 'ú', 't') 4
# ('b', 'i', 'k') 3
# ('s', 'y', 'n') 4
# ('t', 'c', 'p') 3
# ('c', 'p', ' ') 3
# ('á', 's', '!') 4
# ('í', 'c', 'h') 1
# ('g', ' ', 'u') 3
# ('l', 'f', 'í') 1
# ('w', 'e', ' ') 4
# ('(', 'p', 'd') 4
# ('p', 'd', 'l') 2
# ('d', 'l', ')') 2
# ('a', 'h', 'z') 1
# ('h', 'z', 'a') 1
# ('a', 'k', 'b') 1
# ('u', 'b', 'ó') 1
# ('”', ' ', 'u') 1
# ('(', 'i', ')') 4
# ('(', 'd', ')') 4
# ('"', '¿', 'h') 1
# ('d', 'y', '"') 3
# ('y', '"', 's') 1
# ('"', 's', ' ') 1
# ('(', 'a', 'a') 2
# ('a', 'a', ')') 1
# ('s', 'í', '”') 2
# ('j', 'a', ':') 4
# ('é', 'n', 'g') 3
# ('a', 'i', 'p') 3
# (' ', 't', 't') 1
# ('t', 't', 'p') 3
# ('n', 's', '”') 4
# ('i', 'e', '-') 3
# ('j', 'a', 'í') 4
# ('í', 'l', ' ') 3
# ('s', 'h', 'v') 2
# ('h', 'v', 'i') 1
# ('c', 'e', '”') 3
# ('r', 'ó', 'b') 2
# ('l', 'a', ';') 2
# ('e', 'l', '»') 2
# ('l', '»', ' ') 4
# ('»', ' ', 'd') 4
# ('t', 'r', '@') 2
# ('r', '@', 's') 2
# ('@', 's', ' ') 3
# ('@', 's', '.') 1
# ('l', 'l', 'l') 2
# (':', 'h', ',') 2
# ('e', 'j', 'í') 4
# ('¿', 't', 'a') 3
# ('b', 'o', '?') 1
# (' ', 'l', '@') 1
# ('l', '@', 's') 1
# ('s', ',', 'y') 1
# (',', 'y', ' ') 4
# ('n', 'n', 's') 4
# ('n', 's', 'y') 2
# ('y', 'l', 'v') 4
# ('a', 'h', 'h') 2
# ('h', 'h', ' ') 4
# ('a', '.', 'g') 2
# ('.', 'g', '.') 4
# ('g', '.', 'a') 1
# ('u', 'p', 'd') 2
# ('p', 'd', 'i') 1
# ('d', 'i', 'k') 3
# ('e', 'x', 'q') 4
# ('x', 'q', 'u') 4
# ('t', 'í', 'r') 4
# ('r', '-', 'p') 3
# ('d', ' ', 'z') 4
# ('¡', 'l', 'l') 2
# ('n', 'l', 'u') 1
# ('"', 'd', 'é') 3
# ('n', '-', 'w') 3
# ('-', 'w', 'u') 1
# ('w', 'u', 'r') 1
# ('r', 't', 't') 3
# ('n', 'n', 'b') 1
# ('b', 'e', 'g') 4
# ('e', 'g', '.') 2
# ('e', ' ', 'º') 3
# ('º', ' ', 'e') 1
# (',', '%', '"') 1
# ('%', '"', ',') 3
# ('á', ' ', 'é') 2
# ('l', '-', 'i') 1
# ('g', 'u', 'á') 1
# ('u', 'á', 'p') 1
# (' ', 'í', 'm') 1
# (' ', 'e', 'k') 4
# ('í', 'p', 't') 4
# ('m', 'i', 'q') 2
# ('n', 't', 'ò') 1
# ('t', 'ò', 'n') 1
# ('ò', 'n', 'i') 1
# ('u', 'd', 'h') 3
# ('d', 'h', 'o') 3
# ('k', 'a', '.') 4
# ('¿', 'v', 'a') 4
# ('y', 's', ':') 2
# ('t', ' ', ':') 3
# ('e', 'j', '.') 2
# ('ñ', 'o', '!') 2
# ('g', 'o', 'u') 4
# ('e', 't', '"') 4
# ('t', '"', ' ') 4
# ('(', 'n', ' ') 1
# ('v', 'o', ')') 3
# ('i', 'l', 'c') 3
# ('“', 'a', 'y') 1
# ('í', 's', '”') 3
# ('a', '.', ':') 1
# (':', ' ', '–') 2
# (' ', '–', 'n') 3
# ('–', 'n', 'o') 2
# ('d', 'o', 'i') 4
# ('o', 'b', 'á') 4
# ('i', 'k', 't') 3
# ('k', 's', 'i') 1
# ('i', 'n', '-') 4
# ('"', 'p', 'é') 1
# ('y', ' ', '¡') 3
# ('¡', 'a', 'y') 4
# ('¿', 't', 'í') 1
# (' ', '–', 'm') 3
# ('–', 'm', 'u') 2
# ('p', 'i', 'j') 3
# ('o', 'ñ', 'ó') 3
# ('m', 'p', 'ó') 3
# ('a', '-', 'á') 1
# ('-', 'á', 'g') 1
# ('n', '-', 'o') 2
# ('-', 'o', 'l') 1
# (' ', 'x', 's') 3
# ('x', 's', 't') 3
# ('p', 'l', 'c') 2
# ('(', 'r', 'a') 2
# (' ', 'w', 't') 4
# ('w', 't', 'a') 2
# ('u', '.', 's') 2
# ("'", 'l', 'i') 4
# ('g', 'u', ' ') 3
# ('p', 'o', 'v') 4
# ('o', 'p', 'k') 2
# ('p', 'k', 'i') 3
# ('(', 'b', 'á') 1
# ('é', 'n', ')') 1
# ('o', 'd', 'n') 2
# (' ', ':', ',') 3
# (':', ',', '.') 1
# (' ', 'u', ',') 2
# ('c', 'é', ',') 1
# ('l', 'd', 'p') 1
# ('d', 'p', 'l') 1
# ('e', 'l', 'n') 3
# ('l', 'n', 'o') 1
# ('m', 'y', ',') 3
# ("'", 'w', 'w') 1
# ('‘', 'b', 'r') 1
# ('i', 'g', 'é') 3
# ('(', 'i', '.') 1
# ('c', ' ', 'j') 4
# (' ', '“', ' ') 4
# ('“', ' ', 's') 1
# ('e', 't', '”') 1
# ('t', '”', ' ') 4
# ('“', 'f', 'a') 3
# ('d', 'j', 's') 2
# ('l', '.', 'c') 1
# ('y', 's', 'a') 2
# ('h', ' ', 'k') 2
# ('s', 's', 'l') 3
# ('ú', 'l', '.') 2
# ('l', 'a', 'í') 1
# ('n', 'b', 'c') 2
# ('i', 's', '’') 1
# ('(', 'i', 'p') 3
# ('m', 'ó', 'd') 3
# ('ó', 'd', 'u') 3
# ('d', 'f', '"') 1
# ('f', '"', '.') 1
# ('h', 'r', 'é') 4
# ('m', 'c', '”') 1
# ('c', '”', ',') 2
# ('a', '-', 'o') 2
# ('-', 'o', 't') 2
# ('i', 'z', 'h') 3
# ('z', 'h', 'n') 3
# ('h', 'n', 'i') 4
# ('n', 'ó', 'v') 3
# ('ó', 'v', 'g') 2
# ('v', 'g', 'o') 2
# ('n', 'y', 'd') 3
# (' ', '–', 't') 2
# ('–', 't', 'i') 1
# ('n', 'o', '–') 1
# ('o', '–', ',') 3
# ('k', 'r', 'o') 4
# ('l', 't', 'c') 1
# ('t', 'c', 'i') 1
# (' ', 'j', 'n') 2
# ('j', 'n', 'e') 2
# ('r', '-', ',') 3
# (' ', 'o', 'w') 2
# ('b', ' ', ',') 3
# ('u', 'n', 'p') 2
# ('n', 'p', 'r') 2
# ('s', ',', 'v') 1
# (',', 'v', 'i') 2
# ('b', 'í', 's') 1
# ('s', 'n', '.') 3
# ('n', 's', '?') 3
# ('ó', ' ', '$') 3
# ('y', 'c', 'h') 4
# ('o', '-', 'l') 4
# (' ', 'v', ',') 2
# ('o', ',', 'y') 2
# ('a', 'm', 'z') 3
# ('m', 'z', 'i') 1
# ('k', 'i', 'v') 1
# ('(', 'e', 'q') 1
# ('c', '.', ')') 3
# ('n', 'a', 'í') 2
# ('a', 'í', ' ') 2
# (' ', 'h', ':') 4
# ('h', ':', '.') 2
# ('u', 'y', 'n') 1
# ('y', 'n', ',') 3
# ('l', '-', 'l') 1
# (' ', 'g', '?') 1
# ('g', '?', ' ') 2
# ('c', ' ', '¿') 3
# ('m', 'm', 's') 2
# ('m', 's', '?') 1
# ('i', 'l', '?') 4
# ('w', 'u', 'h') 1
# ('o', 'w', 'b') 4
# ('w', 'b', 'a') 1
# ('k', 'r', 'u') 4
# ('a', '-', 't') 4
# ('-', 't', 'u') 1
# ('"', 'd', 'j') 1
# ('ñ', 'o', '-') 2
# ('“', 'r', 'a') 3
# ('g', 's', '”') 1
# ('a', 'b', 'j') 1
# ('b', 'j', ' ') 1
# ('j', ' ', 'h') 4
# ('+', ' ', 'y') 3
# ('j', 'p', ' ') 3
# ('a', 'd', "'") 4
# ('"', 'o', ' ') 4
# ('t', 'y', 'r') 3
# ('“', '¿', 'e') 1
# ('p', 'i', ':') 1
# ('t', 'z', 'y') 1
# ('i', 'c', 'p') 1
# ('c', 'p', 'a') 2
# ('o', 'p', 'm') 1
# ('p', 'm', 'e') 1
# ('z', '-', 'c') 4
# ('“', 'r', 'o') 4
# ('–', 'e', 's') 1
# ('ñ', 'a', '–') 1
# ('p', 'í', 'd') 2
# ('l', 'y', '.') 4
# ('n', 'm', 'ú') 1
# ('o', 'p', 'v') 2
# ('r', 'i', '"') 2
# ('a', 'k', 'r') 3
# ('o', 'v', 'á') 1
# ('n', 'ú', 't') 4
# ('«', 's', 'i') 4
# ('n', ' ', ';') 3
# ('d', 'd', '.') 2
# ('c', 'í', 'c') 3
# ('í', 'c', 'l') 3
# ('w', ' ', 'r') 3
# ('i', 's', ':') 3
# ('n', 's', 'n') 4
# ('o', 's', 'y') 2
# ('s', 'r', 'n') 1
# ('d', 'u', 'f') 3
# ('f', 'e', 'k') 1
# ('e', 'k', '.') 3
# ('j', 'a', 'k') 3
# ('é', 'n', 'o') 2
# ('o', 'e', 'w') 3
# ('r', 'z', ',') 1
# ('“', 's', 'ó') 2
# ('e', ' ', '”') 2
# ('“', 'i', 'd') 1
# ('h', 's', 'u') 2
# ('h', ' ', ':') 1
# ('-', ' ', 'w') 2
# ('"', 'o', 's') 4
# (' ', 't', 'z') 3
# ('z', 'a', 'v') 3
# ('a', ':', '’') 1
# (':', '’', '‘') 1
# ('’', '‘', 't') 1
# ('‘', 't', 'a') 1
# ('u', 'c', 'y') 1
# ('o', '"', '-') 2
# ('"', '-', '.') 3
# ('c', 't', 'j') 1
# ('t', 'j', ')') 1
# ('j', ')', '.') 2
# ('h', 'é', ',') 3
# ('"', '¿', 'n') 3
# (' ', '¿', 'f') 1
# ('¿', 'f', 'u') 1
# ('s', 'o', 'j') 4
# ('k', 'l', 'u') 4
# ('p', ' ', ':') 1
# ('r', '-', 'a') 2
# ('-', 'a', '-') 1
# ('p', 'i', 'v') 4
# ('(', 'c', 'r') 4
# ('‘', 'e', 's') 1
# ('b', 'e', '’') 1
# ('e', '’', '.') 1
# ('(', ' ', 'g') 2
# ('ñ', 'a', "'") 1
# ('t', 's', "'") 3
# ('v', 'ó', ',') 1
# ("'", 'd', 'r') 2
# ('v', 'e', "'") 3
# (' ', 'g', 'c') 3
# ('g', 'c', 'p') 1
# ('c', 'p', 'h') 1
# ('-', '"', 's') 1
# ('a', '"', '-') 1
# (' ', ':', '-') 3
# (':', '-', ' ') 2
# ('c', 'e', 'q') 2
# (' ', 'w', 'í') 1
# ('w', 'í', 'l') 1
# ('í', 'l', 'm') 3
# ('d', ')', ':') 1
# ('f', 'c', 'c') 3
# ('c', 'c', ',') 2
# ('t', 'u', 'é') 1
# ('d', 'e', 'h') 4
# ('‘', 'c', 'a') 3
# ('a', 'e', 'i') 3
# ('(', 's', 'h') 2
# ('s', 'h', 'c') 1
# ('h', 'c', 'p') 1
# ('c', 'p', ')') 2
# ('(', 'n', 'u') 4
# ('c', ' ', 'u') 2
# ('u', 'n', 'l') 1
# ('f', 'y', '.') 2
# ('i', 'd', 'f') 1
# ('a', 'u', "'") 1
# ('u', "'", ' ') 3
# ('s', '-', 'n') 2
# ('-', 'n', 'e') 2
# ('e', 'o', 'h') 3
# ('r', 'f', 'l') 2
# ('e', 'd', ':') 4
# ('g', 's', 't') 3
# ('o', 'e', 'b') 3
# ('i', '-', 'm') 1
# ('a', 't', 'v') 4
# ('t', 'v', 'a') 1
# ('i', 'ñ', 'ó') 4
# ('p', 'r', 'ú') 4
# ('t', 'í', 'v') 2
# ('á', 'l', 'g') 4
# ('g', 'e', 'b') 2
# ('e', 'o', 'm') 4
# ('c', 't', '"') 1
# ('t', '"', '.') 4
# ('b', 'ú', ':') 1
# ('ú', ':', ' ') 1
# ('n', 'á', 'r') 3
# ('t', 's', ')') 3
# ('v', 'l', 'd') 1
# ('g', 'ü', 'í') 4
# ('ü', 'í', 's') 3
# (' ', 'z', 'b') 1
# ('z', 'b', 'i') 1
# ('k', 'o', 'w') 3
# ('w', 's', 'k') 4
# ('t', 'h', 'c') 2
# ('h', 'c', ',') 2
# ('h', 'ú', 'm') 4
# ('z', 'a', 'e') 1
# ('l', ' ', '—') 4
# (' ', '—', 'd') 4
# ('—', 'd', 'e') 3
# ('e', 's', '—') 4
# ('—', ' ', 'n') 1
# (' ', 'é', ' ') 4
# ('u', 'k', 'o') 2
# ('o', "'", 'h') 1
# ('p', 'e', ':') 1
# (' ', '‘', 't') 4
# ('‘', 't', 'i') 1
# ('s', 't', '’') 1
# ('t', '’', ' ') 2
# ('g', 'r', 'ú') 4
# ('ú', 'a', 's') 2
# ('b', 'ó', ':') 2
# ('d', 'í', '.') 1
# ('n', 'g', 'w') 4
# ('g', 'w', 'a') 4
# ('o', 's', 'ú') 1
# ('s', 'ú', 'a') 4
# (' ', '(', '/') 1
# ('(', '/', '/') 1
# ('/', '/', ')') 2
# ('/', ')', ' ') 1
# ('d', 'e', "'") 4
# ('c', 't', 'm') 2
# ('t', 'm', '.') 1
# (' ', 'y', 'h') 1
# ('y', 'h', 'u') 1
# ('g', 'h', 'u') 1
# ('a', 'm', '?') 3
# (' ', 'j', 'l') 4
# ('j', 'l', 'o') 2
# ('v', 'e', '?') 1
# (' ', 'g', 's') 3
# ('g', 's', 'k') 1
# ('a', ' ', '´') 4
# (' ', '´', 'd') 2
# ('´', 'd', 'á') 1
# ('s', 'o', '´') 1
# ('o', '´', ' ') 2
# ('´', ' ', 'p') 3
# ('s', 'g', 'l') 3
# ('b', 'i', 'q') 1
# ('b', ' ', 'j') 1
# ('‘', 'j', 'h') 2
# ('j', 'h', 'o') 4
# ('o', 'n', '’') 3
# ('n', '’', ' ') 4
# ('‘', 'e', 'l') 3
# ('r', 'o', '’') 2
# ('o', '’', '.') 2
# ('g', 'u', 'g') 4
# ("'", 'w', 'o') 1
# ('r', 'k', 's') 4
# ('k', 's', 'h') 3
# ('p', 's', "'") 1
# ('s', 'a', ';') 3
# ('"', '(', 'l') 1
# ('g', 'í', 'm') 3
# ('l', 'í', ':') 1
# ('p', 't', '-') 1
# ('t', '-', 'g') 1
# ('-', 'g', 'e') 2
# ('c', 'e', '*') 1
# ('e', '*', '.') 1
# ('*', '.', ' ') 1
# ('n', 'ó', 'r') 4
# ('t', 'o', 'h') 1
# ("'", 'b', 'e') 3
# ('q', ' ', 'c') 2
# ('z', 'á', 'r') 3
# ('p', 't', ' ') 4
# ('i', 'z', 'u') 4
# ('z', 'u', 'h') 3
# ('u', 'h', 'o') 3
# ('k', 'a', 'g') 2
# ('f', 'o', 'e') 2
# ('w', 'o', 'm') 2
# ('i', 'c', ')') 4
# ('p', 'p', 'o') 4
# ('c', 'm', 'b') 4
# ('m', 'b', '.') 4
# ('c', 'h', "'") 2
# ('h', "'", ' ') 4
# (' ', '—', 'p') 4
# ('—', 'p', 'o') 2
# ('r', 'a', '—') 2
# ('a', '—', '.') 1
# ('g', 'i', 'h') 1
# ('i', 'h', 'o') 1
# ('s', 'u', ',') 3
# ('o', "'", 'b') 1
# ("'", 'b', 'r') 4
# ('t', '-', 'o') 1
# ('-', 'o', "'") 1
# ('o', "'", 'k') 1
# ("'", 'k', 'e') 1
# ('a', 'f', 'k') 1
# ('f', 'k', 'a') 1
# ('n', 'á', ',') 4
# ('n', 'd', 'á') 4
# ('d', 'á', 'r') 4
# (' ', 'j', 't') 2
# ('j', 't', 'a') 1
# ('l', 'ó', '"') 1
# ('–', 'e', 'n') 4
# ('e', 'r', '–') 3
# ('r', '–', ' ') 3
# ('–', ' ', 'h') 4
# ('f', 'l', '.') 2
# (' ', 'b', 'g') 1
# ('b', 'g', 'h') 1
# ('g', 'h', 's') 1
# ('h', 's', 't') 2
# ('r', 'y', ')') 1
# ('h', 'a', '?') 2
# ('‘', 'j', 'o') 1
# ('e', ' ', '’') 2
# ('’', ' ', 'n') 2
# ('c', 'n', ' ') 3
# ('c', 'k', 'p') 1
# ('k', 'p', 'o') 2
# ('u', 'e', '?') 3
# ('d', 's', 'p') 2
# ('s', 'p', 'm') 1
# ('x', 'i', '"') 3
# ('k', 'o', 'i') 1
# ('v', 'o', 'g') 4
# ('r', "'", 's') 4
# ('t', 'o', 'w') 3
# ('n', ' ', '&') 2
# ('&', ' ', 'c') 3
# ('c', 'é', 'i') 2
# ('i', 'b', '.') 4
# (' ', '@', 'k') 2
# ('@', 'k', 'i') 1
# (' ', ':', '/') 1
# (':', '/', ' ') 2
# ('/', ' ', 'l') 3
# ('z', '-', 'g') 3
# (' ', 'u', 'ñ') 4
# ('a', 'y', "'") 4
# ('i', 'c', 'v') 1
# ('c', 'v', ',') 1
# ('t', 'é', 'p') 4
# ('é', 'p', 'h') 2
# ('i', 'u', ')') 2
# ('á', 's', ')') 3
# (' ', 'p', 'è') 1
# ('p', 'è', 'r') 1
# ('á', 's', 'q') 3
# ('"', 'e', 'f') 4
# ('(', 'e', 'a') 1
# (' ', 'h', 'ä') 1
# ('h', 'ä', 'k') 1
# ('ä', 'k', 'k') 1
# ('k', 'k', 'i') 1
# ('z', 'a', '…') 3
# ('l', 'd', 'm') 4
# ('(', 's', 't') 4
# ('k', 'i', 'c') 4
# ('c', 'k', '-') 3
# ('k', '-', 'a') 1
# (' ', 'x', '-') 1
# ('x', '-', 'm') 1
# (' ', 'ó', 'v') 3
# ('ó', 'v', 'u') 3
# ('n', 'm', ' ') 3
# ('k', 's', 'a') 4
# ('v', 'i', 'ć') 1
# ('i', 'ć', ',') 1
# ('ć', ',', ' ') 1
# ('m', 'o', 'w') 1
# ('o', 'w', 'r') 1
# ('w', 'r', 'y') 1
# ('.', ' ', '‘') 1
# (' ', '‘', 's') 3
# ('‘', 's', 'e') 2
# ('l', 's', '’') 1
# ('’', ' ', 'y') 3
# ('p', 'c', ')') 2
# ('p', 'p', '-') 3
# ('p', '-', 'a') 3
# ('u', 'f', 'j') 1
# ('f', 'j', 'a') 1
# ('x', ' ', '(') 2
# (' ', '(', '+') 2
# ('(', '+', ',') 1
# ('+', ',', '%') 1
# ('z', 'a', 'y') 3
# ('i', ' ', '…') 1
# ('-', 's', '.') 3
# (' ', '«', 'f') 3
# ('«', 'f', 'u') 1
# ('i', 'l', '»') 2
# (';', ' ', '«') 1
# ('«', 'm', 'i') 2
# ('(', 'o', 'p') 2
# ('b', 'k', ',') 1
# ("'", 'o', 'r') 4
# ('s', 'h', "'") 2
# ('r', '.', 'e') 1
# ('.', 'e', '.') 3
# ('e', '.', 'm') 1
# ("'", 'o', 'u') 2
# ('i', 'f', 'h') 1
# ('f', 'h', 'í') 1
# ('e', 'x', '/') 1
# ('x', '/', 'd') 1
# ('/', 'd', 'a') 2
# ('n', 'ó', 'o') 1
# ('ó', 'o', 's') 1
# ('g', 'o', 'e') 3
# ('x', 'o', 'c') 2
# ('ó', ' ', 'ú') 2
# ('s', "'", '"') 4
# ('t', 'á', '?') 1
# ('á', '?', ' ') 2
# ('i', 'u', '-') 4
# ('u', '-', 'v') 2
# (' ', 'q', 'i') 3
# ('q', 'i', 'r') 1
# ('a', 'l', 'è') 2
# ('l', 'è', 'n') 2
# ('è', 'n', 'c') 3
# ('e', 't', 'l') 4
# (' ', 's', 'z') 2
# ('s', 'z', 'e') 1
# ('n', 'n', ',') 4
# ('p', ' ', 'u') 4
# ('u', 'z', 'n') 3
# ('z', 'n', 'o') 2
# ('m', 'y', 'a') 3
# ('p', 's', 'g') 1
# ('s', 'g', ' ') 1
# ('m', 'é', 'j') 2
# ('é', 'j', 'i') 2
# ('i', 'a', 'h') 3
# ('s', 's', 'í') 2
# ('s', 'í', 'o') 1
# ('s', ',', 'b') 1
# (',', 'b', 'a') 1
# ('r', 'e', 'á') 3
# ('m', '-', ' ') 3
# ('ª', ' ', 'd') 4
# (' ', 'v', 'd') 4
# ('v', 'd', 's') 4
# ('s', 'l', '?') 1
# ('r', 'n', 'u') 4
# ('w', 'a', 'c') 3
# ('z', ')', ',') 3
# ('e', 'f', 'á') 4
# (' ', "'", '¿') 3
# ("'", '¿', 'e') 1
# ('h', 't', 'e') 3
# ('y', 'a', 'u') 1
# ('d', 'y', '.') 3
# ('a', 'y', 'p') 3
# ('r', 'o', '…') 4
# ('z', 'k', 'y') 3
# ('k', 'y', ':') 1
# ('l', 'é', 'p') 3
# ('b', '"', ' ') 3
# ('t', 'p', 's') 4
# ('u', 's', '?') 2
# ('(', 'o', 'j') 3
# (' ', '"', 'x') 1
# ('"', 'x', 'o') 1
# ('x', 'o', 'l') 2
# ('w', ' ', 'l') 2
# ('w', 'l', ' ') 4
# (' ', 'x', 'l') 2
# ('x', 'l', 'v') 1
# ('l', '-', ',') 1
# ('a', 'c', 'p') 3
# ('c', 'p', 'v') 2
# ('j', 'u', 'h') 1
# ('v', 'o', '-') 2
# ('-', 'e', 'v') 1
# ('p', 'u', 'p') 4
# ('m', ' ', 'g') 3
# ('t', 'h', 'n') 4
# ('e', 'd', '”') 4
# ('d', '”', '.') 3
# ('v', 'a', 'u') 2
# ('u', 'd', 'd') 3
# ('r', 'p', 's') 1
# ('p', 'p', '"') 4
# ('p', '"', ',') 2
# ('a', 'ñ', 'é') 2
# ('ñ', 'é', 'n') 1
# ('ó', 't', 'a') 4
# ('f', 'í', 'l') 3
# ('“', 'p', 'i') 4
# ('m', '.', 'c') 1
# ('e', 'g', 'y') 1
# ('g', 'y', 'p') 1
# ('y', 'p', 't') 1
# ('z', 'e', 'p') 2
# ('h', 'y', 't') 1
# ('x', 'o', 'f') 2
# ('i', 'l', ')') 3
# ('á', '"', '.') 3
# ('f', 'a', '?') 1
# ('n', 'v', 'á') 1
# ('s', 'é', 'n') 4
# ("'", "'", 'r') 1
# ('h', 'w', 'i') 1
# ('r', 'ú', ',') 4
# ('‘', 'e', '-') 1
# ('e', '-', 'r') 3
# ('e', 'r', '’') 3
# ('r', '’', ' ') 1
# ('’', ' ', 'd') 3
# ('“', 's', 'í') 2
# ('–', 'a', 'g') 4
# ('k', 'i', '–') 1
# ('i', '–', ',') 2
# ('u', 'a', ')') 4
# ("'", 'j', 'u') 4
# ('o', "'", '?') 1
# ("'", '?', ',') 1
# ('…', ' ', '"') 2
# ('f', ' ', 'w') 2
# ('y', 'o', '-') 1
# ('-', ' ', 'j') 1
# ('¡', 'c', 'o') 4
# ('h', 'í', '!') 3
# ('(', 'j', 'e') 3
# ('e', 'c', ')') 4
# ('ó', 's', 'm') 3
# ('s', 'é', 'r') 2
# (' ', '"', '-') 3
# ('"', '-', 'm') 2
# ('(', '"', 'p') 2
# ('a', '"', ')') 3
# ('"', ')', ',') 2
# ('m', ' ', 'x') 2
# ('w', 'i', 'r') 4
# ('a', 't', '&') 2
# ('t', '&', 't') 2
# ('&', 't', ' ') 2
# ('"', ' ', '¿') 4
# ('¡', 'a', 'l') 1
# ('i', 'o', '!') 2
# ('-', 'a', 'q') 2
# ('p', 'a', 'o') 4
# ('l', 'i', '"') 2
# ('i', '"', '.') 3
# ('b', 'o', "'") 1
# (' ', 'v', 'p') 1
# ('v', 'p', 'h') 2
# ('m', 's', 'e') 1
# ('o', "'", ':') 1
# ('e', '-', 't') 3
# ('-', 't', 'e') 2
# ('u', 't', 'í') 2
# ('r', 'á', 'v') 4
# ('(', 'b', 'l') 4
# ('d', 'i', ')') 1
# ('f', 't', 'e') 4
# ('m', 'y', 'e') 2
# ('•', ' ', 'a') 1
# ('t', 'á', '"') 1
# ('h', 'p', '.') 2
# ('e', 'ó', 'g') 3
# ('n', 'i', 'i') 3
# (' ', 'á', 'p') 1
# ('n', 'é', 'n') 4
# ('a', 'i', 'u') 3
# ('w', 'n', 's') 2
# ('“', 'a', 'p') 3
# ('(', 'y', ')') 2
# ('k', 'a', "'") 2
# ('z', 'á', ',') 4
# ("'", 'f', 'e') 4
# ('e', 'm', '.') 2
# ('e', 'x', 'j') 3
# ('x', 'j', 'u') 3
# (' ', '@', 'h') 3
# ('@', 'h', 'e') 2
# ('d', 'y', 'b') 1
# ('t', '.', '.') 4
# ('.', ' ', '’') 1
# ('e', '-', 'i') 2
# ('-', 'i', 's') 3
# ('z', 'm', 'i') 4
# ('t', 's', 'y') 2
# ('(', 'n', 'y') 1
# ('t', 's', 's') 2
# ('•', ' ', 'c') 2
# ('j', 'e', 'j') 4
# ('j', 'e', '…') 1
# ('e', '…', 'l') 1
# ('…', 'l', 'i') 1
# ('i', 'i', 'e') 2
# ('ú', 'd', '.') 1
# ('f', 'o', '"') 3
# ('í', 't', 'm') 2
# ('(', 'm', 'ú') 1
# ('+', ' ', 'a') 1
# ('+', ' ', 's') 4
# ('x', 'o', ')') 1
# ('ñ', 'o', '?') 2
# ('z', 'z', ',') 4
# ('x', 'a', 'r') 3
# ('s', 't', 'c') 3
# ('q', ' ', 'i') 1
# ('q', ' ', 'g') 3
# ('a', 'p', 'f') 2
# ('p', 'f', ')') 2
# ('s', 'ó', '”') 2
# ('ó', '”', ',') 2
# ('p', 'n', 'o') 2
# ('t', 'á', ')') 1
# ('r', 'c', '"') 1
# ('c', '"', ',') 1
# ('r', 'á', ')') 2
# ('e', 'h', 'ú') 1
# ('h', 'ú', 'y') 1
# ('ú', 'y', 'e') 1
# ('d', ' ', ',') 4
# ('¿', 's', 'ó') 2
# ('p', 'a', '?') 3
# ('k', 'o', 'j') 2
# ('m', 'i', 'y') 4
# ('o', 'd', 'f') 2
# ('é', 'u', '.') 1
# (' ', '@', 'i') 1
# ('@', 'i', 'n') 1
# ('n', 'e', '!') 3
# ('"', 'c', 'ú') 1
# ('h', 's', 'b') 2
# ('s', 'b', 'c') 2
# ('e', 'r', '…') 4
# (' ', '“', '@') 1
# ('“', '@', 'g') 1
# ('@', 'g', 'u') 2
# ('g', 'u', 'y') 3
# ('u', 'y', 'k') 1
# ('y', 'k', 'a') 1
# ('c', 'k', '”') 2
# ('k', '”', ',') 2
# ('ó', 'f', 'u') 2
# ('u', 'l', '”') 1
# ('“', 'c', 'i') 2
# ('-', 'h', 'i') 2
# ('i', '-', ' ') 1
# ('«', 'c', 'i') 2
# ('t', 'e', '»') 4
# ('»', ' ', 'l') 3
# ('d', 'l', 'o') 4
# ('n', 'y', 'o') 4
# ('m', 'l', 'u') 1
# ('i', 'é', 'l') 4
# ('e', 'y', 'r') 4
# ('y', 'r', 'r') 1
# ('d', 'p', ',') 2
# ('(', 'c', 'd') 3
# ('c', 'é', 'd') 2
# ('í', 'g', 'o') 4
# ('f', '.', 'c') 4
# ('l', 's', 'á') 1
# ('s', 'á', 'm') 1
# ('a', 'f', 'n') 2
# ('f', 'n', 'e') 3
# ('ó', 'n', 'g') 4
# ('s', '.', 'm') 2
# ('m', '.', 'i') 1
# ('.', 'i', '.') 3
# ('n', 't', 'j') 3
# ('t', 'j', 'u') 3
# ('j', 'u', 'ï') 3
# ('u', 'ï', 'c') 3
# ('ï', 'c', '.') 2
# (' ', ' ', '$') 2
# ('$', ' ', 'c') 2
# ('$', ' ', 'p') 3
# ('e', 'u', 'e') 4
# ('n', 'i', 'á') 1
# ('i', 'á', 'r') 2
# ('a', 'r', 'ß') 1
# ('r', 'ß', ',') 1
# ('ß', ',', ' ') 1
# ('a', 'k', 'í') 1
# ('k', 'í', 'e') 4
# ('p', 't', 'é') 2
# ('‘', 'p', 'r') 2
# ('m', 'a', '’') 2
# ('i', '-', 'd') 3
# (' ', 'u', 'j') 1
# ('o', 'h', ' ') 2
# ('u', 's', 'n') 1
# (' ', "'", '-') 2
# ("'", '-', '-') 2
# ('-', '-', "'") 2
# ('-', "'", ' ') 1
# ('p', 's', 'k') 3
# ('t', 'í', 'b') 4
# ('"', 'e', 'd') 3
# ('e', 'n', 'ç') 2
# ('ç', 'o', ' ') 1
# ('l', 'h', 'ó') 1
# (' ', ',', ')') 1
# (',', ')', '.') 2
# ('x', 'i', 'i') 4
# ('i', 'p', '-') 1
# ('p', '-', 't') 1
# ('a', 'n', 'x') 4
# ('n', 'x', 'i') 4
# (';', ' ', 'v') 1
# ('j', 'i', '.') 2
# ('l', ' ', ';') 2
# (' ', ';', 'p') 1
# (';', 'p', 'a') 1
# ('u', 'd', 'c') 4
# ('d', 'c', 'o') 3
# ('e', 'm', 't') 4
# ('m', 't', 's') 3
# ('c', 's', 'n') 3
# ('z', ' ', '¿') 2
# (' ', '@', 't') 3
# ('@', 't', 'i') 1
# ('i', 's', '-') 1
# ('s', '-', 't') 3
# ('-', 't', 'i') 3
# ('"', 'p', 'p') 2
# ('e', 'd', 'l') 3
# ('r', 'm', 'ú') 4
# ('m', 'ú', 'd') 4
# ('“', 'b', 'l') 4
# ('n', 's', ')') 1
# ('b', 'c', ':') 2
# ('c', ':', ' ') 2
# ('y', 'e', 'g') 2
# ('m', '.', 's') 3
# ('s', '.', '/') 1
# ('.', '/', '.') 1
# ('í', 'n', '?') 2
# ('e', 'w', ',') 4
# ('a', '-', 'f') 3
# ('x', 'u', 'b') 1
# ('"', 'o', 'p') 2
# ('p', 'h', '"') 1
# ('h', '"', ',') 2
# ('d', '.', 'i') 1
# ('i', '.', 'f') 1
# ('f', '.', ')') 1
# ('a', 'v', 'à') 1
# ('v', 'à', ' ') 1
# ('à', ' ', '(') 2
# ('s', ' ', '`') 1
# (' ', '`', 'e') 1
# ('`', 'e', 'l') 1
# ('n', 'o', '`') 1
# ('o', '`', ',') 1
# ('`', ',', ' ') 1
# ('r', 't', 'ú') 4
# ('t', 'ú', 's') 1
# ('d', ' ', '/') 1
# ('o', ' ', '”') 1
# ('p', 's', ')') 3
# ('í', ' ', 'k') 2
# ('t', 'k', 'i') 3
# (' ', ' ', 'º') 2
# ('r', 'é', '.') 3
# ('b', 'u', 'í') 3
# ('“', 'a', 'g') 1
# ('j', '.', 'b') 1
# ('.', 'b', '.') 2
# ('•', ' ', 'r') 2
# ('p', 'á', 's') 3
# ('b', 'ú', 'm') 2
# ('g', '"', ',') 3
# (' ', 'p', 'v') 4
# ('p', 'v', 'e') 2
# ('(', 's', 'c') 2
# ('s', 'c', 't') 2
# ('c', 't', ')') 1
# ('t', 'á', 'v') 2
# ('á', 'v', 'o') 2
# ('w', 'a', 'p') 3
# ('"', '¿', 'v') 2
# ('¿', 'v', 'i') 2
# ('h', 'k', 'o') 2
# ('¿', 'p', 'r') 3
# ('"', 'i', 'b') 2
# ('¿', 's', 'u') 4
# ('x', '/', 'h') 1
# ('/', 'h', 'c') 1
# ('h', 'c', 'm') 1
# ('c', 'm', '/') 1
# ('m', '/', 'n') 1
# ('/', 'n', 'm') 1
# ('n', 'm', 'n') 1
# ('m', 'n', '/') 2
# ('n', '/', 'a') 1
# ('/', 'a', 'q') 1
# ('a', 'q', 'f') 2
# ('q', 'f', ' ') 2
# ('f', 'e', '”') 2
# (' ', '(', '@') 1
# ('(', '@', 'p') 1
# ('@', 'p', 'r') 1
# ('c', 'i', 'i') 1
# ('i', 'i', 'p') 1
# (' ', 'c', ',') 1
# ('-', 'm', '.') 3
# ('t', 't', 'g') 4
# ('t', 'g', 'a') 3
# ('r', 't', ';') 1
# ('t', ';', ' ') 1
# ('r', ' ', '–') 3
# ('d', 'a', '—') 2
# ('—', ' ', 'q') 4
# ('(', 'w', 'i') 2
# ('f', 'i', ')') 2
# ('j', 'a', 'é') 4
# ('a', 'é', 'n') 4
# ('(', ' ', 'i') 1
# ('n', ' ', 'í') 4
# ('z', 'm', 'o') 1
# ('r', 'z', 'y') 2
# ('a', 'v', 'n') 2
# ('v', 'n', '.') 2
# ('t', 'n', 'ó') 1
# ('m', 'p', '”') 1
# ('p', '”', ' ') 1
# ("'", 'p', 'l') 4
# ('s', 't', "'") 2
# ('(', 'l', 'i') 4
# ('c', 'á', 't') 4
# ('b', 'á', 't') 2
# ('e', 's', 'z') 1
# ('s', 'z', 'k') 1
# ('m', 'u', ' ') 3
# ('g', 'a', ';') 1
# ('d', 'r', 'z') 1
# ('z', 'e', 'j') 1
# ('e', 'j', ' ') 2
# ('j', ' ', 'w') 1
# ('w', 'a', 'j') 2
# ('k', 'r', 'z') 1
# ('z', 'y', 's') 2
# ('y', 's', 'z') 1
# ('s', 'z', 't') 1
# ('z', 't', 'o') 1
# ('f', ' ', 'z') 1
# ('b', 'í', ',') 1
# ('v', 'í', 'b') 1
# ('í', 'b', 'o') 1
# ('y', 'a', 'w') 1
# ('e', 'f', 'n') 2
# ('(', 'r', ')') 2
# ('á', '.', '.') 2
# ('ü', 'í', ',') 1
# ("'", 'j', 'o') 3
# ('y', 'l', 'y') 2
# ('u', 'e', '-') 3
# ('u', 'a', '-') 1
# ('e', 'd', 'k') 1
# ('d', 'k', 'e') 2
# ('h', 'e', 'u') 3
# ('á', 'f', 'a') 3
# ('m', 'í', 'm') 1
# ('(', 'a', 'ú') 3
# (' ', 'l', 'ö') 1
# ('l', 'ö', 'w') 1
# ('ö', 'w', ' ') 1
# ('w', ' ', 'o') 3
# ('s', 'u', 'ó') 1
# (' ', 'l', 's') 2
# ('l', 's', 'd') 3
# ('e', 'l', '…') 2
# ('l', '…', ' ') 3
# ('g', 'n', 'é') 4
# ('w', 's', 'l') 1
# ('h', 'a', '…') 2
# ('…', ' ', 'm') 4
# ('i', 'à', ' ') 3
# ('p', 'v', ')') 2
# ('o', '"', ';') 4
# ('s', '"', ';') 1
# ('n', 'í', 'o') 1
# ('f', 'f', 'm') 2
# ('j', 'á', 'u') 3
# ('ñ', 'e', 's') 2
# ('i', 'n', 'p') 4
# ('á', 'r', 'l') 1
# ('¡', 'h', 'o') 2
# ('o', 'i', '"') 1
# ('s', 'g', 'é') 1
# ('d', ' ', '–') 2
# ('d', 'a', '–') 2
# ('–', ' ', 'm') 4
# ('s', 'n', 's') 1
# ('é', 'l', '?') 2
# ('"', 'z', 'o') 2
# ('g', 'e', 'c') 4
# ('c', 'á', 'z') 4
# ('a', 'd', 'f') 3
# ('u', 'j', 'í') 3
# (' ', '‘', 'a') 4
# ('‘', 'a', 's') 2
# ('é', ' ', 'k') 1
# ('—', 's', 'u') 1
# ('o', 's', '—') 4
# ('p', 'é', 'i') 2
# ('–', 'd', 'i') 4
# ('r', 'o', '–') 1
# ('y', 'a', 'y') 4
# (',', 'e', 'n') 2
# ('a', 's', 'ì') 1
# ('s', 'ì', 'l') 1
# ('ì', 'l', 'i') 1
# ('u', 'e', ';') 1
# ('-', '.', '.') 1
# ('n', 'x', '.') 2
# ('.', ' ', 'z') 1
# (' ', 'á', 't') 4
# ('á', 't', 'o') 4
# ('s', 'í', '?') 4
# ('(', 's', 's') 3
# ('t', 't', ')') 1
# ('«', 't', 'o') 1
# ('b', 'ú', '.') 3
# ('w', 's', 't') 1
# ('c', 'á', 'u') 2
# ('n', 'o', 'á') 3
# ('o', 'á', 'c') 2
# ('l', 'á', 'x') 1
# ('á', 'x', 'o') 1
# ('r', 'b', 'á') 3
# ('b', 'á', 'e') 4
# ('á', 'e', 'v') 1
# ('v', ' ', 'r') 4
# ('a', 'd', '—') 2
# ('d', '—', '—') 1
# ('—', '—', 's') 1
# ('—', 's', 'o') 2
# ('t', 'o', 'i') 4
# (' ', 's', 'b') 2
# ('¿', 'v', 'o') 3
# ('s', 'á', 's') 3
# ('i', 'o', 'h') 1
# ('l', 't', 'z') 3
# ('o', 'l', '-') 1
# ('l', '-', 'b') 2
# ('k', ' ', 'u') 3
# ('n', 'd', '"') 2
# ('j', '.', 'd') 2
# ('.', 'd', '.') 3
# ('v', 'ó', 'l') 4
# ('ó', 'l', 'q') 1
# ('m', 'a', ';') 2
# ('o', '-', 'g') 3
# ('o', 'b', ',') 3
# ('r', 'w', 'i') 3
# ('g', 'o', '-') 1
# ('-', 'a', 'n') 3
# ('r', 'm', 'v') 1
# ('m', 'v', 'i') 1
# (' ', 'a', 'x') 3
# ('a', 'x', 'l') 1
# ('x', 'l', ' ') 1
# ('t', ' ', 'z') 3
# ('“', 's', 'h') 4
# ('n', 'í', 'v') 2
# ('r', 'n', 't') 2
# ('o', 'e', 'y') 3
# ('k', ' ', 'b') 4
# ('$', '.', '.') 3
# ('a', 'i', 'v') 2
# ('u', 'p', 's') 1
# ('“', 'd', 'a') 4
# ('m', 'p', 'ú') 1
# ('p', 'ú', 's') 2
# (' ', 'o', '.') 3
# ('o', '.', 'n') 1
# ('.', 'n', '.') 2
# ('l', 'o', 'x') 2
# ('e', ' ', '´') 3
# (' ', '´', 'e') 1
# ('´', 'e', 'l') 1
# ('o', 'z', '´') 1
# ('z', '´', ' ') 1
# ('“', 'a', 'm') 1
# ('j', ' ', 'o') 1
# ('«', 'r', 'e') 3
# ('e', 'r', '»') 2
# ('-', 'a', 'h') 1
# ('a', 'z', '-') 1
# ('z', '-', 'd') 1
# ('-', 'd', 'u') 4
# ('ñ', 'a', '?') 4
# ('t', 'c', ')') 3
# ('l', ',', 'p') 1
# (',', 'p', 'o') 3
# ('s', 'm', 'n') 1
# ('m', 'n', ',') 1
# ('p', 't', ',') 3
# ('b', 'l', 'í') 4
# ('e', 't', 'k') 3
# ('a', 's', 'b') 2
# ('l', 'z', ' ') 2
# (' ', 'h', '&') 1
# ('h', '&', 'm') 1
# ('&', 'm', ' ') 1
# ('t', 'y', '"') 1
# ('f', '.', 'g') 2
# ('.', 'g', 'a') 2
# ('s', ' ', ')') 3
# ('d', 'ó', 'c') 1
# ('ó', 'c', 'i') 1
# ('y', 'n', 'c') 4
# ("'", 'a', 'g') 2
# ("'", 'o', 't') 1
# ('l', 'd', 'k') 1
# ('d', 'k', 'l') 1
# ('“', ' ', 'n') 1
# ('t', 'ó', 't') 1
# ("'", "'", 'e') 2
# ('r', ' ', '@') 3
# ('@', 'f', 'o') 1
# ('+', ' ', '@') 1
# ('+', ' ', 'x') 1
# ('f', 'á', ',') 2
# ('.', '-', 's') 1
# ('.', '-', 'a') 1
# ('-', 'a', 'p') 4
# ('-', 's', ' ') 2
# ('l', 't', 's') 3
# ('t', 's', 'i') 3
# ('(', 't', ')') 3
# ('l', 'm', 'b') 2
# ('m', 'b', '"') 1
# ('c', 'o', 'w') 4
# ('k', 'i', ':') 1
# ("'", 'w', 'i') 1
# (':', ' ', '*') 1
# (' ', '*', ' ') 2
# ('*', ' ', 's') 1
# ('s', ' ', '·') 1
# ('·', ' ', 'e') 2
# ('o', 'g', '!') 1
# ('g', '!', ' ') 1
# ('e', '-', 's') 4
# ('-', 's', 'o') 4
# ('e', '-', 'n') 4
# ('b', 'o', 'k') 4
# ('«', 't', 'e') 2
# ('r', 'é', 'f') 2
# ('é', 'f', 'e') 2
# ('“', 'y', ' ') 4
# ('s', 's', 'n') 1
# ('t', 'v', 'd') 1
# ('v', 'd', 'c') 1
# ('a', 'd', '-') 3
# ('d', '-', 'p') 1
# ('l', 'g', 'é') 4
# (' ', 'á', 'u') 2
# (' ', 'a', ':') 1
# ('l', 'm', ',') 2
# ('v', ' ', 'f') 2
# ('e', '-', 'e') 3
# ('e', '-', 'g') 2
# ('(', 'u', 's') 3
# ('$', '.', ')') 1
# ('ó', 'n', 'y') 3
# (' ', ' ', ';') 4
# (' ', ';', ')') 2
# (';', ')', ' ') 2
# (')', ' ', '@') 3
# (' ', '@', 'b') 4
# ('@', 'b', 'e') 2
# (':', ',', ' ') 2
# ('n', '-', 't') 3
# ('n', '-', 'e') 3
# ('m', 'o', '!') 1
# (' ', '!', ',') 4
# ('u', 'i', 'q') 3
# ('o', 'e', 'v') 2
# ('(', 'b', 'm') 1
# ('m', 'w', ')') 1
# ('w', ')', '.') 1
# ('t', 'p', 'p') 2
# ('p', ' ', 'f') 4
# ('b', 'c', 'n') 2
# ('c', 'n', 'r') 2
# ('@', 's', 'o') 2
# ('s', 'v', 'o') 1
# ('+', ' ', 'm') 1
# ('u', '$', '.') 1
# ('o', '"', ':') 2
# (' ', '«', 'a') 2
# ('«', 'a', ' ') 1
# ('i', 'e', '»') 1
# ('i', '-', 'p') 2
# ('-', 'p', 'v') 1
# ('n', 'a', ';') 3
# ('t', 'o', '!') 3
# ('(', 'f', 'r') 3
# ('o', 'b', ')') 1
# ('b', ')', '.') 3
# ('t', 'é', 'v') 3
# ('é', 'v', 'e') 4
# ('n', ' ', '—') 1
# (' ', '—', 'l') 2
# ('—', 'l', 'a') 1
# ('t', 'a', '—') 1
# ('o', 'x', 't') 1
# ('ª', ' ', 'f') 2
# ('é', 'c', 'u') 3
# ('k', 's', "'") 1
# ("'", 'f', 'u') 4
# ('h', 'i', "'") 3
# ('s', 'l', 'ú') 1
# ('l', 'ú', 'c') 2
# ('ú', 'c', 'i') 2
# ('p', 'v', '?') 1
# ('v', '?', ' ') 1
# ('c', 'p', '/') 1
# ('p', '/', 'i') 4
# ('/', 'i', 'p') 2
# ('v', 'é', ',') 1
# ('u', 'h', 'i') 2
# ('w', 'n', 'f') 1
# ('e', ' ', '/') 3
# ('/', ' ', 'k') 1
# (' ', 'k', 'v') 1
# ('k', 'v', ',') 1
# ('m', 'v', 'a') 1
# ('k', 'u', 'c') 3
# ('u', 'c', 'z') 3
# ('c', 'z', 'y') 4
# ('y', 's', 'n') 1
# ('s', 'n', 'k') 1
# ('n', 'ó', 'c') 3
# (' ', 't', 'ª') 1
# ('t', 'ª', ',') 1
# ('ª', ',', ' ') 1
# ('(', 'm', 'é') 4
# (' ', '@', 'q') 1
# ('@', 'q', 'w') 1
# ('q', 'w', 'r') 1
# ('w', 'r', 't') 1
# ("'", 's', 'p') 2
# ('r', '-', 'm') 1
# ('k', ' ', "'") 3
# ('“', '¿', 'y') 2
# ('¿', 'y', 'o') 2
# ('w', 'b', 'o') 2
# ('m', 'p', 'é') 1
# ('p', 'é', 'a') 1
# ('f', 'a', 'y') 4
# ('é', 'l', 'v') 3
# ('b', ' ', '.') 4
# ('&', ' ', 'f') 3
# ('s', 's', ':') 2
# ('i', 'g', 'á') 4
# ('g', 'á', 'i') 3
# ('"', ' ', '%') 1
# (' ', '%', '"') 4
# ('u', 'r', ':') 3
# ('h', 'u', 'j') 2
# ('o', 'l', 'ú') 1
# ('l', 'ú', 'm') 1
# (' ', '–', '¿') 2
# ('–', '¿', 'c') 1
# ('¿', 't', 'u') 2
# ('e', 'c', 'p') 1
# (' ', 'i', 'x') 4
# ('i', 'x', 'c') 1
# ('x', 'c', 'h') 2
# ('o', 't', 'b') 4
# ('t', 'b', 'a') 4
# (' ', 'x', 't') 2
# ('a', 'g', 'é') 2
# ('m', 'm', ',') 2
# ('y', 'o', 'k') 3
# ('…', '.', 'c') 2
# ('.', 'c', 'r') 2
# ('o', 'a', 'g') 4
# ('(', 'i', 'm') 4
# ('l', ')', ':') 1
# ('r', 'v', 'á') 1
# ('v', 'á', 'e') 1
# ('r', 'e', ';') 4
# ('d', 'n', '.') 2
# ('a', '-', 'r') 1
# ('-', 'r', 'i') 1
# ('p', 'o', 'a') 2
# ('o', ' ', ';') 2
# ('v', 'i', 'á') 3
# ('t', 'r', 'l') 3
# ('r', 'l', '+') 2
# ('l', '+', 'v') 1
# ('+', 'v', ' ') 1
# ('r', 'y', 'l') 3
# ('n', 'ó', 'f') 3
# ('"', 'h', 'í') 1
# ('i', 'e', 'u') 3
# ('é', ' ', 'é') 1
# ('z', ' ', ',') 3
# ('e', 'q', 'e') 1
# ('q', 'e', 'c') 1
# ('f', ')', '.') 3
# ('m', 'l', 's') 3
# (' ', '.', '"') 2
# ('.', '"', ' ') 2
# ('t', 'a', '–') 2
# ('a', 'r', '’') 1
# ('r', '’', '.') 3
# ('i', 'l', '”') 4
# (' ', 'd', 'l') 4
# ('a', '"', ':') 1
# ('(', '"', 'e') 2
# ('m', 'y', '.') 2
# (' ', 'r', 'ú') 4
# ('r', 'ú', 's') 2
# ('c', 'o', 'q') 4
# ('j', ' ', 'e') 4
# ('“', 't', 'u') 4
# (' ', 'k', 'f') 1
# ('k', 'f', 'z') 1
# ('f', 'z', '.') 1
# ('p', 'f', 'w') 1
# ('f', 'w', 'a') 1
# ('t', ')', 'a') 1
# (')', 'a', 'p') 1
# ('(', 'a', 'e') 4
# ('a', 'e', 'a') 3
# ('o', 'm', 't') 2
# ('m', 't', 'o') 2
# ('k', 's', 'v') 1
# ('-', 'n', 'i') 4
# ('¡', 'y', ' ') 2
# ('i', 'e', '!') 1
# ('e', 'n', '…') 4
# ('n', '…', ' ') 3
# ('j', 'i', 'h') 3
# ('(', 'p', 'f') 2
# ('p', 'f', 'l') 2
# ('l', 'p', ' ') 3
# ('a', 'q', 's') 1
# ('q', 's', 'a') 1
# ('m', 'i', 'v') 2
# ('s', 's', 'u') 3
# ('ó', 'n', '!') 2
# ('v', 'g', ' ') 3
# ('v', 'g', ',') 3
# ("'", 'm', 'o') 3
# ('u', 'z', "'") 1
# ('z', "'", ' ') 2
# ('d', 'ú', 'e') 1
# ('l', 'h', 'i') 3
# ("'", 'r', 'í') 1
# ('í', 'o', "'") 2
# ('«', 'd', 'i') 2
# ('a', 'r', '»') 1
# ('r', '»', '.') 1
# ('-', 'b', 'r') 3
# ('o', 'e', 'f') 3
# ('n', 'i', ')') 2
# ('o', 'z', '"') 2
# ('w', 'h', 'o') 4
# ('r', ' ', '…') 1
# ('…', ' ', 'z') 1
# ('w', 'i', 'y') 4
# ('b', 'l', 'á') 3
# ('l', 'á', 'b') 4
# ('n', 'á', 'b') 3
# ('u', 'd', '\ufeff') 1
# ('d', '\ufeff', ' ') 1
# ('\ufeff', ' ', 'f') 2
# ('a', 'y', 'm') 3
# ('—', ' ', 't') 2
# ('h', 'í', 'n') 3
# ('l', 's', 'b') 1
# ('v', 'r', 'e') 3
# ('f', 't', 'i') 3
# ('e', '/', ' ') 2
# ('/', ' ', '…') 2
# ('r', 'u', 'q') 2
# ('a', 'í', 'm') 2
# ('í', 'm', 'o') 3
# ('"', 's', 'c') 1
# ('i', 'g', 'c') 4
# ('g', 'c', '.') 1
# (' ', '-', '>') 1
# ('-', '>', ' ') 1
# ('>', ' ', 'r') 1
# ('o', 'r', '’') 2
# ('r', '’', 's') 2
# ('n', 's', 'ú') 1
# ('s', 'c', ')') 2
# (' ', '“', 'é') 2
# ('“', 'é', 'l') 1
# ('n', 'á', 'j') 3
# ('á', 'j', 'e') 3
# ('k', 'y', 'l') 3
# ('y', 'n', 'g') 2
# ('o', 's', '¡') 1
# ('s', '¡', '¡') 1
# ('¡', '¡', '¡') 3
# ('¡', '¡', ' ') 2
# ('¡', ' ', 'x') 1
# ('(', 'h', 'i') 1
# ('s', 'á', 'r') 3
# (':', ' ', ',') 4
# ('o', 'i', ',') 3
# ('e', 'n', 'à') 1
# ('n', 'à', 'g') 1
# ('à', 'g', 'i') 2
# ('i', 'x', 'o') 4
# ('e', 'p', ')') 1
# ('p', ')', ',') 3
# ('(', 'g', 'o') 3
# ('l', 'l', '"') 2
# (' ', 'j', 'h') 2
# (' ', 'y', 'm') 2
# ('y', 'm', 'c') 2
# ('m', 'c', 'a') 2
# ("'", 'f', 'i') 3
# ('l', '-', 'f') 3
# ('-', 'f', 'o') 4
# ('u', 'r', "'") 4
# ('n', 'd', ';') 3
# (' ', ' ', 'ó') 3
# ('¿', 'n', 'i') 1
# ('z', '-', 'r') 2
# ('-', 'r', 'u') 2
# ('l', '-', 'g') 3
# ('i', 't', 'g') 2
# ('t', 'g', 'u') 1
# ('s', 't', 'l') 4
# ('t', 'h', 'w') 2
# ('c', 'd', 'c') 1
# ('d', 'c', '.') 1
# ('f', 'e', "'") 3
# ("'", 'b', 'u') 1
# ('é', 's', ';') 1
# ('n', 'ó', ',') 2
# (' ', 'l', 'f') 1
# ('l', 'f', 'c') 1
# ('p', 'a', "'") 3
# ('a', 'p', 'm') 1
# ('p', 'm', 'a') 1
# ('j', 'd', 'u') 1
# ('d', ' ', 'á') 1
# ('e', '-', 'm') 4
# ('ü', 'e', ' ') 4
# ('e', 'e', 'w') 2
# ('e', 'w', '.') 3
# ('c', 'í', 's') 2
# ('í', 's', 'c') 3
# ('a', 'a', 's') 1
# ('e', 'c', 'd') 1
# ('c', 'd', 'ó') 1
# ('d', 'ó', 't') 1
# ('o', 'c', 'ú') 2
# ('ú', 'p', 'a') 1
# ('¿', 'u', 's') 2
# ('i', 'ó', '?') 2
# ('°', ' ', ',') 1
# ('x', ' ', 'o') 2
# ('p', 'ó', ',') 2
# ('y', 'i', 'm') 1
# ('o', "'", "'") 3
# ('o', 'd', 'k') 1
# ('d', 'k', 'i') 1
# ('t', 'h', 's') 2
# ('h', 's', 'o') 1
# (' ', '!', ')') 1
# ('!', ')', ' ') 1
# ('l', 'e', 'á') 4
# (':', 'h', ' ') 3
# ('k', 'a', 'p') 3
# ('z', 'y', ';') 1
# ('y', ';', ' ') 3
# ('a', 'o', 't') 3
# ('(', 'a', 'f') 4
# ("'", 't', 'í') 2
# ('u', '.', 'e') 1
# ('.', 'e', '"') 1
# ('n', '-', 'm') 3
# ('z', '-', 'm') 1
# ('í', 'n', '"') 3
# ('i', 'r', 'f') 1
# ('r', 'f', ',') 1
# (' ', '–', 'o') 2
# ('–', 'o', ' ') 2
# ('á', ' ', '-') 2
# ('e', 't', 'j') 2
# ('t', 'j', 'a') 3
# ('e', ' ', '″') 1
# (' ', '″', ' ') 1
# ('″', ' ', 'c') 1
# ('x', ' ', ',') 2
# ('x', 'o', 'o') 2
# ('n', 'o', 'é') 3
# ('o', 'é', ' ') 3
# ('i', 'k', ';') 1
# ('k', ';', ' ') 1
# (';', ' ', 'f') 4
# ('r', 'd', 'á') 4
# ('g', '-', 'h') 2
# ('-', 'h', 'y') 1
# ('"', '¡', 'a') 1
# ('¡', 'a', ' ') 3
# ('–', 's', 'o') 3
# ('c', 'l', 's') 1
# ('l', 's', 's') 2
# ('u', 'e', 'q') 1
# ('f', 'e', '-') 1
# ('r', 'a', '–') 2
# ('e', ' ', '¢') 3
# (' ', 'q', 'f') 1
# ('q', 'f', 'h') 1
# ('f', 'h', 'd') 1
# (' ', '.', ')') 3
# ('”', ' ', 'n') 3
# ('e', 'o', 'u') 3
# ('o', 'u', 'f') 3
# ('u', 'f', ' ') 2
# ('n', ' ', '¿') 2
# ('¿', 't', 'ú') 1
# ('c', 'o', '´') 1
# ('o', '´', 's') 1
# ('´', 's', ' ') 3
# ('x', 't', ' ') 2
# ('w', ' ', 'i') 1
# ('e', '.', 'o') 2
# ('.', 'o', 'r') 3
# ('x', 'o', 'd') 4
# ('l', 'g', 'b') 1
# ('g', 'b', 't') 1
# ('b', 't', ' ') 1
# ('o', 'ñ', 'e') 1
# ('t', 'n', ' ') 1
# ('j', 'o', '-') 3
# ('c', 'u', 'é') 4
# ('s', 'l', 'ó') 3
# ('ó', 'g', 'a') 3
# ('m', 'd', 'd') 4
# ('i', 'b', ',') 4
# (' ', 'z', 'á') 1
# ('a', 'a', 'z') 1
# (',', ' ', '/') 2
# ('/', ')', '?') 1
# ('t', 'ó', 'd') 1
# ('u', 'e', 'h') 4
# ('/', ' ', 'u') 2
# ('s', 't', 'g') 3
# ('t', 'g', 'é') 1
# ('b', ' ', '"') 4
# ('r', 't', 'm') 4
# ('t', 'm', 'u') 2
# ('n', 'd', ')') 1
# ('t', 'í', 'l') 1
# ('s', 'b', 'n') 1
# ('b', 'n', '-') 1
# ('p', 'a', ':') 3
# ('e', 's', 'y') 2
# ('y', 's', ',') 4
# ('d', 'u', 'i') 3
# ('-', 'o', 'n') 1
# ('a', 'f', '.') 3
# ('x', 'd', 'i') 4
# ('a', 'l', '—') 2
# ('l', '—', 'c') 1
# ('—', 'c', 'o') 2
# ('l', 'f', 'g') 2
# ('c', 'h', 'ä') 3
# ('h', 'ä', 'u') 3
# ('ä', 'u', 'b') 2
# ('"', '¡', 'v') 2
# ('¡', 'v', 'a') 4
# ('t', 'i', '!') 2
# ('i', '!', ',') 2
# ('a', 'o', '!') 1
# ('o', 'k', 'b') 2
# ('k', 'b', 'u') 3
# ('c', 'n', 'm') 4
# ('n', 'm', 'v') 4
# ('m', 'v', ')') 3
# ('v', ')', '.') 4
# ('a', 'o', 'i') 1
# ('l', 'l', '`') 2
# ('l', '`', 's') 2
# ('`', 's', ' ') 3
# ('c', 'h', 'f') 3
# ('h', 'f', ')') 2
# ('h', 'f', ',') 1
# ('h', 'f', '.') 1
# (',', ' ', '«') 3
# ('«', 'p', 'u') 1
# ('ó', 'n', '»') 2
# ('n', '»', '.') 2
# ('l', 'k', 's') 4
# ('k', 's', 'w') 4
# ("'", 'l', 'á') 2
# ('ª', ' ', 'e') 2
# ('h', 'w', 'e') 1
# ('a', 'y', 'ú') 2
# ('y', 'ú', 'n') 1
# (' ', 'x', 'u') 4
# ('x', 'u', 'n') 3
# ('d', 'j', 'e') 1
# ('d', 'u', 'ñ') 1
# ('a', 'n', ';') 4
# ('a', 't', 'y') 4
# ('(', ' ', 'k') 4
# ('s', 'í', ':') 3
# ('s', 'u', 'u') 4
# ('k', 'y', 'i') 4
# ('y', 'i', ' ') 1
# ('b', 's', '?') 2
# ('r', 'é', '"') 2
# ('é', '"', ',') 3
# ('a', 'e', 't') 4
# ('n', 'p', 'l') 1
# ('g', ' ', 'w') 2
# ('o', 'l', ':') 4
# ('i', 'r', '”') 3
# ('s', 'z', 'a') 1
# ('h', 'y', 'n') 2
# ('a', 't', 'w') 1
# ('l', 'k', 'q') 1
# ('k', 'q', 'u') 1
# ('n', '.', 't') 1
# ('.', 't', 'v') 1
# ('v', ' ', ')') 1
# ('l', 'v', 'é') 4
# ('v', 'í', ' ') 4
# ('m', 'd', 'a') 2
# ('d', 'm', ' ') 3
# ('"', 'r', 'i') 3
# ('l', ' ', '´') 2
# (' ', '´', 'c') 2
# ('´', 'c', 'e') 1
# ('é', 's', '´') 1
# ('s', '´', ' ') 2
# ('´', ' ', 'e') 2
# ('l', 'o', '…') 3
# ('h', 'l', 's') 1
# ('t', 'r', 'ö') 1
# ('r', 'ö', 'm') 2
# ('ö', 'm', ' ') 1
# ('‘', 'p', 'e') 2
# ('ó', 'n', '’') 1
# (' ', '"', ')') 1
# ('e', 'i', 'p') 4
# ('i', 'p', 'z') 2
# ('p', 'z', 'i') 2
# ('i', 'g', '.') 2
# ('f', 'o', ':') 1
# ('á', 'p', 'a') 3
# ('y', 'u', 'e') 4
# ('l', "'", 'e') 2
# ("'", 'e', 'q') 1
# ('d', 'e', 'k') 4
# ('l', 'b', ',') 1
# ('s', 'p', ')') 3
# ('r', 'd', 'ô') 1
# ('d', 'ô', 'm') 1
# ('ô', 'm', 'e') 1
# ('i', 'á', 's') 3
# ('i', 'e', "'") 3
# ('e', "'", 's') 4
# ('z', 'o', 'f') 4
# ('f', 'r', 'é') 2
# ('j', 'o', 'g') 1
# ('o', 'g', 'v') 1
# ('g', 'v', ',') 1
# ('u', 'f', ',') 4
# ('l', 'l', '?') 1
# ('é', ' ', 'á') 3
# ('f', 'l', '-') 1
# ('l', '-', 'c') 2
# ('-', 'c', 'i') 3
# (' ', 'j', '&') 1
# ('j', '&', 'j') 1
# ('&', 'j', ' ') 2
# (' ', 's', 'j') 2
# ('s', 'j', 'i') 1
# ('s', 't', 'v') 1
# ('t', ' ', '.') 2
# ('f', 'f', '-') 3
# ('f', '-', 'r') 1
# ('–', 'm', 'a') 1
# ('a', 's', '–') 4
# ('r', 'k', 'l') 3
# ('i', 'a', 'k') 2
# ('e', 'w', 'l') 1
# ('t', 't', '-') 1
# ('t', '-', 'p') 2
# ('n', 'z', '"') 1
# ('t', 'ó', '”') 2
# ('ó', '”', ' ') 2
# ('‘', 'l', 'o') 2
# ('b', 'y', '’') 1
# ('y', '’', '.') 1
# ('b', 'ó', '.') 2
# ('(', ':', ')') 1
# (':', ')', ',') 1
# ('a', 'p', 'd') 3
# ('s', 's', 'w') 2
# ('s', 'w', 'o') 3
# ('m', 's', 'k') 2
# ('v', 'd', ',') 3
# ('(', 'a', 'b') 4
# ('a', 'b', 'm') 2
# ('b', 'm', ')') 2
# ('y', 'a', 'o') 4
# ('w', '.', 'w') 1
# ('.', 'w', 'd') 1
# ('w', 'd', 'l') 1
# ('d', 'l', '.') 1
# ('l', '.', 'o') 1
# ('g', '/', 'e') 1
# ('/', 'e', 's') 3
# ('a', 't', 'j') 1
# ('t', 'j', 'e') 1
# ('c', 'k', ':') 2
# ('p', 'a', 'h') 4
# ('(', 'o', 'n') 2
# ('n', 'u', ')') 2
# ('‘', 'j', 'u') 3
# ('j', '.', 'c') 2
# ('c', '.', 'b') 1
# ('r', 'ó', ':') 2
# ('u', ' ', '‘') 1
# (' ', '‘', 'v') 2
# ('‘', 'v', 'i') 1
# ('d', 'a', '’') 3
# ('’', '.', '.') 1
# ('g', ' ', 'j') 3
# ('h', '.', ',') 2
# ('t', 'ú', 'o') 1
# ('ú', 'o', ' ') 2
# ('m', 'u', 'g') 4
# ('u', 'g', 'y') 1
# ('g', 'y', 'e') 3
# ("'", 'c', 'l') 1
# ('o', "'", 't') 1
# ('b', ' ', '-') 1
# ('e', 'a', 'y') 3
# ('“', 'o', 'f') 1
# (' ', 'i', ',') 3
# ('u', 'l', '"') 3
# (' ', 'f', '-') 4
# ('f', '-', ',') 1
# ('e', 'f', 'y') 2
# ('c', 'y', 'a') 1
# (' ', 'p', '-') 1
# ('p', '-', 'd') 1
# ('-', 'd', ' ') 3
# ('w', 'k', ' ') 3
# ('a', '-', ')') 1
# ('v', '-', '-') 1
# ('c', 'm', '.') 1
# ('i', '-', 'k') 2
# ('-', 'k', 'u') 1
# ('t', 'i', '"') 3
# ('e', 'y', 'z') 2
# ('y', 'z', 'a') 2
# ('z', 'a', 'o') 2
# ('¡', 's', 'í') 1
# ('c', 'a', '!') 4
# ('l', 'á', 'e') 3
# ('-', 'a', 'ñ') 1
# ('i', 'ó', '-') 1
# ('ó', '-', ' ') 2
# ('a', 'g', 'ú') 2
# ('r', 'c', 'y') 4
# ('z', 'e', 'g') 3
# ('b', ' ', 'b') 4
# ('n', 'i', 'y') 3
# ('f', ' ', 'k') 1
# ('s', 'i', 'h') 1
# ('i', 'h', 'p') 1
# ('h', 'p', 'i') 1
# ('p', 'i', 'w') 1
# ('i', 's', "'") 4
# ...
# ('s', ':', '/') 1
# (':', '/', '/') 1
# ('/', '/', 'w') 1
# ('/', 'w', 'w') 1
# ('‘', 'c', 'u') 1
# ('z', 'u', 'f') 1
# ('i', 'v', '"') 1
# ('v', '"', ' ') 1
# ('e', 'r', '/') 1
# ('r', '/', 'm') 1
# ('/', 'm', 'u') 1
# ('á', 'n', '”') 1
# (' ', '“', ',') 1
# ('p', ',', 'f') 2
# (',', 'f', 'a') 2
# ('%', ' ', '+') 1
# ('n', ' ', '―') 1
# (' ', '―', 'e') 1
# ('―', 'e', 'l') 1
# ('a', 'n', '―') 1
# ('n', '―', ' ') 1
# ('―', ' ', 'y') 1
# ('.', 'j', 'a') 1
# ('d', 'u', 'k') 1
# ('u', 'k', 't') 1
# ('-', 'k', 'o') 1
# ('d', 'i', 'ñ') 1
# ('r', 'z', 'l') 1
# ('n', ',', '"') 1
# (',', '"', 's') 1
# ('n', ')', '"') 2
# ('j', 'o', '–') 1
# ('l', '.', '?') 1
# ('o', '-', 'h') 1
# ('(', '+', '%') 1
# ('+', '%', ')') 1
# ('e', 'k', 'k') 1
# ('x', 's', 'í') 1
# ("'", 'o', 'k') 1
# ('d', 's', ':') 1
# ('i', 'y', 'e') 1
# ('(', 'k', 'i') 1
# ('!', ' ', '"') 1
# ('v', 'a', '!') 2
# ('o', 'n', '»') 1
# ('a', 'ú', 'j') 1
# ('"', '¡', 'l') 1
# ('e', 'd', ')') 3
# ('(', 's', 'n') 1
# ('n', 'b', ')') 1
# ('g', 'i', ':') 1
# (' ', 'l', '-') 1
# ('l', '-', 'v') 1
# ('-', 'v', ' ') 1
# ('r', 'j', 'ó') 1
# ('(', 'v', 'o') 1
# ('v', 'a', 'f') 1
# ('h', 'r', ' ') 1
# ('t', 'ó', ';') 1
# ('s', ' ', '<') 1
# ('u', 'i', "'") 1
# ('k', 'á', 's') 1
# ('a', 'z', 'h') 1
# ('k', '-', '”') 1
# ('-', '”', ' ') 1
# ('f', 'a', 'ñ') 1
# ('s', 'h', 'm') 1
# ('ª', ' ', 't') 1
# ('í', 'o', '?') 1
# ('x', 'i', 'r') 2
# ('m', 'u', 'é') 1
# ('d', 'd', 'l') 1
# (' ', 'd', ')') 1
# ('z', 'k', 'r') 1
# ('c', 'é', 'z') 1
# ('é', 'z', 'a') 1
# (' ', 'q', 'q') 1
# ('q', 'q', ';') 1
# ('q', ';', ' ') 1
# (':', ' ', '`') 1
# ('`', 'c', 'r') 1
# ('l', ',', '"') 1
# ('p', 's', 's') 1
# (' ', 's', 'è') 1
# ('s', 'è', 'q') 1
# ('è', 'q', 'u') 1
# ('m', 'p', 'd') 1
# ('e', 'v', 'à') 1
# ('v', 'à', 'n') 1
# ('à', 'n', 'o') 1
# ('w', 'b', 'i') 1
# ('p', 'y', '.') 1
# ('s', 'h', 'f') 1
# ('h', 'f', 'o') 1
# ('e', 'ó', ':') 1
# ('m', 'ú', 'z') 1
# ('ú', 'z', 'q') 1
# ('u', 'n', '”') 1
# ('“', 'd', 'i') 2
# ('r', "'", "'") 2
# ('p', 'd', 'h') 1
# ('b', 'b', 'm') 2
# ('c', 'y', 'd') 1
# ('b', 'm', 'p') 1
# (' ', 'y', ')') 1
# ('é', 's', ':') 1
# ('(', 'y', 'i') 1
# ('h', 't', '!') 1
# ('o', 'l', 'w') 1
# ('-', 'j', ' ') 1
# ('j', ' ', 'f') 1
# ('”', ' ', '—') 1
# ('t', 'e', '—') 1
# ('—', ' ', '“') 1
# ('u', 'p', 'v') 1
# ('c', 'v', '-') 1
# ('v', '-', '.') 1
# ('a', 'b', '(') 1
# ('b', '(', 'c') 1
# ('a', 'c', 'w') 1
# ('c', 'w', 'o') 1
# (' ', '–', 'l') 2
# ('–', 'l', 'l') 1
# (' ', ' ', '–') 1
# ('–', ' ', 'j') 1
# ('-', 't', 'y') 1
# ('w', 'a', 'q') 1
# ('y', 't', '.') 2
# ('n', 'k', '’') 2
# ('k', '’', 'a') 1
# ('’', 'a', 'y') 1
# (' ', 'q', '’') 1
# ('q', '’', 'e') 1
# ('’', 'e', 'l') 1
# ('f', 'e', 'v') 1
# ('ó', '-', '.') 1
# ('j', 'k', 's') 1
# ('k', 's', 'm') 1
# ('ó', ' ', 'z') 2
# ('l', 'i', '-') 2
# ('o', '…', 's') 1
# ('…', 's', 'u') 1
# ('l', '-', 'j') 1
# ('-', 'j', 'i') 1
# ('(', '"', 'l') 1
# ('l', '"', ')') 1
# ('d', 'ó', '”') 1
# ('a', 'r', 'à') 1
# ('r', 'à', ' ') 1
# ('à', ' ', 'l') 1
# ('(', 't', 'í') 1
# ('d', 'd', 'ú') 1
# ('d', 'ú', '.') 1
# (' ', 'c', "'") 1
# ('c', "'", 's') 1
# ('.', 'r', 'u') 1
# ('s', 'h', 'd') 1
# ('“', 't', 'w') 1
# ('j', 'i', 'v') 1
# (' ', 't', 'x') 1
# ('x', 'a', 'k') 1
# ('-', 'e', 'e') 1
# ('r', 'b', 's') 2
# ('u', 'o', 'a') 1
# ('@', 'd', 'a') 1
# (' ', '+', ',') 1
# ('i', 'v', ')') 1
# ('e', 'w', 'h') 1
# ('(', 'l', 'v') 1
# ('n', 't', 't') 1
# ('l', 'ú', 'e') 1
# ('v', 'a', 'v') 1
# ('c', 'h', 'ú') 1
# ('h', 'ú', ' ') 1
# ('s', 'm', ',') 1
# ('í', 'n', 'f') 1
# ('s', 'u', 'h') 1
# ('v', 'o', 'j') 1
# ('m', 'í', ':') 1
# ('n', 'i', '»') 1
# ('i', '»', ' ') 1
# ('f', 'n', 'a') 1
# ('@', 'h', 'y') 1
# ('p', 'p', "'") 2
# ('p', "'", ' ') 3
# ('l', 'ú', 'o') 1
# ('a', 'u', '"') 1
# ('i', 'c', 'n') 1
# ('f', ' ', 'u') 1
# ('o', 'e', '—') 1
# ('g', 'z', 'h') 1
# ('x', 'e', ',') 1
# ('r', 'l', 't') 1
# ('a', 'k', '»') 1
# ('k', '»', ',') 1
# ('(', 'r', 'b') 1
# ('b', 's', ')') 2
# ('«', 'e', 'm') 1
# ('d', '»', ' ') 1
# ('h', 'm', '"') 1
# ('a', 'n', 'b') 1
# ('n', 'b', ',') 1
# ('o', ')', '…') 1
# (')', '…', 'p') 1
# ('…', 'p', 'e') 1
# ('z', 'p', ',') 1
# ('.', ' ', '…') 1
# ('+', ' ', 'p') 1
# ('‘', 'g', 'a') 1
# ('.', '.', '!') 1
# ('.', '!', ' ') 1
# ('i', 'u', 'c') 1
# ('‘', 'm', 'i') 1
# ('i', 'a', '‘') 1
# ('a', '‘', ' ') 1
# ('‘', ' ', 'i') 1
# ('i', 'b', 'y') 1
# ('b', 'y', ')') 1
# ('t', 'r', 'ú') 1
# ('¡', 's', 'e') 1
# ('/', ' ', 'g') 1
# ('y', 'á', 'b') 2
# ('e', 'f', 'ú') 1
# ('k', 'e', 'h') 1
# ('l', 'e', '–') 1
# ('e', ':', 'v') 1
# (':', 'v', 'a') 1
# ('s', ':', ')') 1
# ('t', 'í', ')') 1
# ('í', ')', '"') 1
# (' ', 'l', 'v') 1
# ('p', 'é', 'g') 1
# ('g', ' ', '&') 1
# ('&', ' ', 'o') 1
# ('u', 'f', 's') 1
# ('e', 'o', 'v') 1
# (' ', 'h', 'z') 1
# ('h', 'z', ' ') 1
# ('p', 'd', 'j') 1
# ('d', 'j', ')') 1
# ('p', 'g', 'm') 1
# ('g', 'm', ',') 1
# ('g', 'u', '.') 1
# ('m', 'g', 'u') 1
# ('.', ' ', 'é') 1
# ('l', 'o', 'k') 3
# ("'", "'", '¡') 1
# ("'", '¡', 'l') 1
# ('¡', 'l', 'i') 1
# ('k', '”', ' ') 1
# ('“', 'e', 'p') 3
# ('p', 'h', '”') 1
# ('u', 's', '”') 1
# ('g', 'i', ')') 1
# ('c', '-', 'c') 1
# ('h', 't', 'w') 1
# ('p', 'k', 'n') 1
# (' ', 'z', ' ') 1
# ('l', 'é', "'") 1
# ('“', 'v', 'i') 1
# ('ú', 's', '”') 1
# ('o', '?', ')') 1
# ('r', 'ó', 'z') 2
# ('ó', 'z', '.') 1
# ('z', 'u', 't') 1
# ('u', 't', '»') 1
# ('d', 'n', ',') 1
# ('t', 'g', 'r') 2
# ('c', ' ', '.') 1
# ('a', '.', ')') 1
# ('d', 'i', '"') 1
# ('"', 't', 'í') 1
# ('c', 'm', 'p') 1
# ('s', 't', '!') 1
# ('v', ' ', 'j') 1
# ('f', 'é', '"') 1
# ('k', 'e', 'd') 2
# ('´', 'f', 'l') 1
# ('"', 'l', "'") 1
# ('g', 's', '.') 1
# ('e', '.', ')') 1
# ('r', '"', '?') 1
# ('n', 'k', 't') 1
# ('(', 't', 'p') 1
# ('p', 'i', 'y') 1
# ('i', 'y', ')') 1
# ('c', 'ú', ')') 1
# ('ú', ')', ',') 1
# ('o', 'f', 'é') 2
# ('f', 'é', 't') 2
# (' ', 'º', 'c') 2
# ('º', 'c', ' ') 1
# ('a', ' ', 'º') 1
# ('º', 'c', '.') 1
# ('w', ' ', '¡') 1
# ('¡', 'q', ' ') 1
# ('l', 'r', ' ') 1
# ('r', 'á', '?') 1
# ('m', 'r', 'o') 1
# (' ', 'y', 'z') 1
# ('y', 'z', ' ') 1
# ('z', ' ', '.') 1
# ('k', 'm', '"') 1
# ("'", 's', 'l') 1
# ('e', 'p', "'") 1
# ('f', 'i', 'v') 1
# ('g', 'h', 'r') 1
# ('d', 'e', 'w') 1
# ('y', '…', '.') 1
# ('m', 'b', 's') 1
# ('(', 'l', 'é') 1
# ('l', 'é', 'a') 1
# ('b', 'a', '-') 1
# ('o', 'd', 'c') 1
# ('p', ')', '-') 1
# (')', '-', ' ') 1
# ('f', 'p', '/') 1
# ('/', 'i', 'c') 1
# ('e', 'y', '?') 1
# (' ', '-', '(') 1
# ('-', '(', '-') 1
# ('d', 'y', 'c') 1
# ('q', 'u', 's') 1
# ('a', 'z', 's') 1
# ('u', ' ', 'ó') 1
# ('c', 'p', 'm') 1
# ('p', 'm', ',') 1
# ('o', 'l', '”') 1
# ('a', 'a', 'p') 1
# ('ó', 'z', ' ') 1
# ('s', ' ', '’') 1
# ('c', 'l', ' ') 1
# ('f', 'c', 'e') 1
# ('r', ')', ';') 1
# ('p', 'u', 'w') 1
# ('u', 'w', 'e') 1
# ('e', 'x', 'b') 1
# ('x', 'b', 'a') 1
# ('"', 'i', ' ') 1
# (' ', 'i', "'") 1
# ('i', "'", 'm') 1
# ("'", 'm', ' ') 1
# ('o', 'i', ';') 1
# ('p', 't', 'v') 1
# ('s', 'ó', '–') 1
# ('d', '-', 'n') 1
# ('t', 'n', '.') 1
# ('n', 'a', '–') 1
# ('a', '–', '.') 1
# ('w', 'a', 'e') 1
# ('k', 'g', 'e') 1
# ('t', 'í', 'd') 1
# ('v', 'o', "'") 1
# ('e', 'é', 'r') 1
# (' ', 'd', '…') 1
# ('t', 'u', ':') 1
# ('n', 'í', 'z') 1
# ('b', 'h', 'u') 1
# ('w', 'y', 'a') 1
# ('i', 'p', '/') 1
# ('p', '/', '/') 1
# ('e', 'ó', 'f') 1
# ('(', 'f', 'p') 1
# ('f', 'p', 'v') 1
# ('p', 'v', '-') 1
# ("'", 'k', '.') 1
# ('u', 'r', 'ú') 1
# ('p', 'h', "'") 1
# ('"', '¡', 'n') 1
# ('¿', ' ', 'p') 1
# ('f', 't', '?') 1
# ('t', '?', ' ') 2
# ('o', 'r', 'h') 1
# ('r', 'h', 'í') 1
# ('(', '.', ')') 1
# ('-', 'n', 'ó') 1
# ('ó', 'v', 'o') 1
# ('t', 'p', ')') 1
# ('p', 'a', '`') 1
# ('`', 's', 'o') 1
# ('“', '…', 's') 1
# ('…', 's', 'e') 1
# (' ', 'x', 'c') 1
# ('w', 'n', ';') 1
# ('a', 'f', 'c') 1
# (' ', 'y', 'í') 1
# ('y', 'í', 'd') 1
# ('y', 'i', 'd') 1
# ('p', 'o', '»') 1
# ('s', 's', 'á') 2
# ('(', 'i', 'o') 1
# ('o', 'v', '-') 2
# ('v', '-', ')') 1
# ('g', 'a', 'ú') 2
# ('a', 'ú', 'c') 2
# ('ú', 'c', 'h') 2
# ('s', '/', 'l') 1
# ('/', 'l', 'a') 1
# ('l', 'o', '/') 1
# ('o', '/', 'l') 1
# ('/', 'l', 'l') 1
# ('p', 's', 'y') 1
# ('(', 'i', 'e') 2
# ('e', 'q', ')') 1
# ('q', ')', ' ') 1
# ("'", 's', "'") 1
# ('h', 't', 'r') 1
# ('-', 'c', 'n') 1
# ('a', 'r', 'ì') 1
# ('r', 'ì', 'a') 1
# ('ì', 'a', ' ') 1
# (' ', 'g', 'ò') 1
# ('g', 'ò', 'm') 1
# ('ò', 'm', 'e') 1
# ('j', 's', '.') 1
# ('e', 'u', ')') 1
# ('f', 'o', '»') 1
# ('h', 'u', ',') 2
# ('n', 'i', 'ç') 1
# ('i', 'ç', 'ã') 1
# ('t', 'a', 'ç') 1
# ('a', 'ç', 'õ') 1
# ('ç', 'õ', 'e') 1
# ('õ', 'e', 's') 1
# ('x', 'a', 't') 1
# ('n', 'u', "'") 1
# ('b', 'e', 'f') 1
# (' ', 'x', 'ó') 1
# ('x', 'ó', 'c') 1
# ('ó', 'c', 'h') 1
# ('x', ' ', '-') 1
# ('v', 'g', '.') 1
# ('á', 'b', 'l') 1
# ('g', ' ', '“') 1
# ('á', 'n', ';') 1
# (' ', '(', '…') 1
# ('(', '…', ')') 1
# ('…', ')', ' ') 1
# ('(', 'i', 'u') 1
# ('e', 'y', 'p') 1
# ('n', 'u', 'ñ') 1
# ('a', 'h', 'j') 1
# ('"', ' ', '¬') 1
# (' ', '¬', '¬') 1
# ('¬', '¬', '.') 1
# ('¬', '.', ' ') 1
# ('f', 'f', '?') 1
# ('f', '?', ' ') 1
# ("'", 'c', 't') 1
# ('c', 't', 't') 1
# ('t', 't', 'u') 1
# ('e', 'h', 'c') 1
# ('r', 'd', 'j') 1
# ('j', ' ', 'b') 1
# ('g', 'b', 'p') 1
# ('t', 'o', '»') 2
# ('k', ' ', '&') 1
# ('l', 's', "'") 1
# ('o', "'", 'd') 1
# ('g', 'o', '»') 1
# ('u', 'm', 'v') 1
# ('m', 'v', 'e') 1
# ('m', 'á', '"') 2
# ('"', 't', 'ú') 1
# ('u', 'k', '?') 1
# ('k', '?', '.') 1
# ('r', 'p', 'í') 1
# ('w', 'u', 'n') 1
# ('d', 'o', 'h') 1
# ('(', 'r', 'y') 1
# ('o', 'a', 'z') 1
# ('e', 'c', '-') 1
# ('c', '-', 'o') 1
# ('-', 'o', 'a') 1
# ('(', 'i', 'f') 1
# ('f', 'f', 'h') 1
# ('f', 'h', 's') 1
# ('h', 's', ')') 1
# ('–', 'l', 'a') 1
# ('e', 'o', '–') 1
# ('b', 'a', 'v') 1
# ('t', 'ó', '"') 2
# ('c', 'e', '…') 1
# ('ñ', 'i', 'm') 1
# (' ', 'u', 'y') 1
# ('p', 'n', ',') 1
# ('h', 'í', '?') 1
# ('h', 'í', ')') 1
# ('r', 'ö', 't') 1
# ('ö', 't', 't') 1
# ('l', 'í', 'r') 1
# ('m', 'e', ':') 1
# ('q', ' ', 'a') 1
# ('i', 'q', '.') 1
# ('b', 'ú', 'k') 1
# ('ú', 'k', 'a') 1
# ('s', 'y', 'e') 1
# (' ', 'c', '?') 1
# ('c', '?', ',') 1
# ('l', '+', 'c') 1
# ('+', 'c', ',') 1
# ('j', 'p', 'm') 1
# ('b', 'c', 'b') 1
# ('c', 'b', ',') 1
# ('a', ')', '-') 1
# (')', '-', ',') 1
# ('u', 'a', '–') 1
# ('¢', ' ', 'q') 1
# ('x', 'e', 'd') 1
# ('u', ' ', '–') 1
# ('w', 'i', 'z') 1
# ('o', 'á', 'm') 1
# ('i', 'i', '!') 1
# ('t', ' ', 'é') 1
# ('t', 'v', 'y') 1
# ('v', 'y', 'n') 1
# ("'", 'y', 'o') 1
# ('t', 'h', "'") 1
# ("'", ' ', '-') 2
# ('r', 'é', '-') 1
# ('é', '-', ' ') 1
# ('n', 'y', 'l') 1
# ('c', 'p', 's') 1
# ('u', 'd', '”') 1
# ('p', 'i', 'h') 1
# ('m', 'i', 'h') 1
# ('n', 'g', 'ä') 1
# ('g', 'ä', 'b') 1
# ('ä', 'b', 'e') 1
# ('a', 'm', 'g') 1
# (' ', '¿', 'r') 2
# ('¿', 'r', 'e') 2
# (' ', 'l', '’') 1
# ('l', '’', 'u') 1
# ('’', 'u', 'm') 1
# ('a', 'h', 'b') 2
# ('h', 'b', 'u') 1
# ('ó', 'b', 'y') 1
# ('@', 'e', 's') 1
# ('a', 'w', 'w') 1
# ('w', 'w', ' ') 1
# ('z', 'o', '!') 1
# ('u', 'f', '.') 1
# ('r', 'g', 'f') 1
# ('g', 'f', 'r') 1
# ('u', 'm', 't') 1
# ('h', 's', 'p') 1
# ('w', 'c', 'd') 1
# ('c', 'd', 'm') 1
# ('s', 'm', '.') 1
# ('l', ',', 'e') 1
# ('“', 'a', 'n') 2
# ('í', '”', '.') 1
# ('y', 'o', ':') 1
# ('f', 'r', ' ') 1
# ('o', '-', 't') 1
# ('r', 'o', '»') 1
# ('n', 'q', ',') 1
# (' ', 'r', 'à') 1
# ('r', 'à', 'd') 1
# ('à', 'd', 'i') 1
# ('i', 'á', 'k') 1
# ('á', 'k', 'i') 1
# ('v', 'l', 't') 1
# ("'", 'n', 'u') 2
# ('u', 's', "'") 1
# ('i', 'v', "'") 1
# ('v', "'", ' ') 1
# ("'", 'i', 'b') 1
# ('d', 'ó', 'm') 1
# ('f', 't', 'í') 1
# ('b', 'i', ':') 1
# ('“', 'i', ' ') 1
# ('n', '’', 't') 1
# ('’', 't', ' ') 1
# ('i', 't', '”') 1
# (' ', '(', '”') 1
# ('(', '”', 'n') 1
# ('”', 'n', 'o') 1
# ('r', '”', ')') 1
# ('o', 'g', 'j') 1
# ('g', 'j', ' ') 1
# ('l', 'u', '-') 1
# ('u', '-', 'r') 1
# (' ', ';', 'd') 1
# (';', 'd', ' ') 1
# ('g', '-', 'w') 1
# (' ', '/', ':') 3
# ('/', ':', ' ') 3
# ('e', ')', ':') 1
# ('í', 'a', '/') 1
# ('/', 's', 'e') 1
# ('o', 'h', 'x') 1
# ('h', 'x', 'x') 1
# ('x', 'x', 'n') 1
# ('x', 'n', 'n') 1
# ('-', 'p', ' ') 1
# ('“', 'd', 'í') 1
# ('f', 'a', 'f') 1
# ('f', 'n', 'i') 1
# ("'", 'i', 'k') 1
# ('o', '’', 'n') 1
# ('’', 'n', 'e') 1
# ('á', 't', 'c') 1
# ('c', 'o', 'k') 1
# ('s', 'y', 'd') 1
# ('y', 'd', 'n') 1
# ('“', 'e', 'f') 1
# ('p', 'ú', 'g') 1
# ('ú', 'g', 'i') 1
# ('s', 'o', ';') 2
# ('ó', '–', ',') 1
# ('c', '.', ',') 1
# ('q', ' ', 's') 1
# ('n', 'p', 'a') 1
# ('l', '-', 'p') 1
# ('á', 'c', 'a') 1
# ('n', 'y', 'p') 1
# ('y', 'p', 'i') 1
# ('s', 'q', 'l') 1
# ('q', 'l', ' ') 1
# ('l', 'z', 's') 1
# ('z', 's', 'e') 1
# ('@', 's', 'a') 1
# ("'", 'á', 'g') 1
# ('g', 'e', '?') 1
# ('u', 'z', '-') 1
# ('"', '(', 'm') 1
# ('h', 'w', 'o') 1
# ('x', 'm', 'u') 1
# ('r', 't', '"') 1
# ('ñ', 'ó', '?') 1
# (':', '-', 'd') 1
# ('e', 'm', 'v') 1
# ('d', 'g', 's') 1
# ('g', 's', 'o') 1
# ('´', 'l', 'a') 1
# ('u', 'e', '´') 1
# ('e', '´', ';') 1
# ('´', ';', ' ') 1
# ('o', 'f', 'l') 1
# ('o', '.', 'c') 1
# ('m', ' ', '-') 1
# ('r', 'é', 'm') 1
# ("'", 's', 'j') 1
# ('i', "'", 's') 1
# ('d', 's', "'") 2
# ('(', "'", 'l') 1
# ('i', "'", ')') 1
# ('w', '.', 'e') 1
# ('u', 'y', 'u') 1
# ('c', 'n', 'd') 1
# ('(', 'b', 'i') 3
# ('o', "'", 'l') 1
# ('‘', 'a', 'n') 1
# (' ', 'z', 'x') 1
# ('z', 'x', ' ') 1
# ('c', '/', 'm') 1
# ('m', 'é', 'm') 1
# (' ', 'l', 'd') 1
# ('d', 'w', 's') 1
# ('m', 'c', 'v') 1
# ('i', 's', 'v') 1
# ('u', 'o', 'c') 1
# ('f', 'e', 'f') 1
# ('e', 'f', 'c') 1
# ('f', 'c', 'a') 1
# ('d', 'c', ')') 1
# ('(', 'p', 'n') 1
# ('p', 'n', 'c') 1
# ('r', 'k', 'h') 1
# (' ', '—', ',') 1
# ('e', 'p', 'm') 1
# ('p', 'm', 'v') 1
# ('“', 'e', 'c') 1
# (' ', 'c', 'k') 1
# ('c', 'k', 'd') 1
# ('k', 'd', '.') 1
# ('w', 'n', '.') 1
# ('z', 'o', "'") 1
# ('h', 'r', 't') 1
# (',', ' ', '•') 1
# ('•', ' ', ':') 1
# ('m', ' ', '•') 1
# ('•', ' ', 'v') 1
# ('x', ' ', ':') 1
# ('b', 't', 'f') 1
# ('d', 'é', ',') 1
# ('´', 's', 'h') 1
# ('o', 'w', '`') 1
# ('w', '`', ' ') 1
# ('`', ' ', 'm') 1
# ('l', 'b', 'l') 1
# ('e', 'v', '"') 1
# ('s', 'g', 'i') 2
# (':', ' ', ':') 1
# ('u', 'q', ' ') 1
# ('´', 'd', 'e') 1
# ('‘', 'c', 'i') 1
# ('‘', 'p', 'o') 1
# ('g', 'o', '’') 1
# ('“', 'l', 'c') 1
# ('o', 's', '“') 1
# ('s', '“', ',') 1
# ('k', 'y', 'd') 1
# ('o', 'j', 'b') 1
# ('j', 'b', 'l') 1
# ('‘', 'o', 'c') 1
# ('c', 'r', 'à') 1
# ('r', 'à', 't') 1
# ('g', 'p', '-') 1
# ('e', 't', 'ú') 1
# ('t', 'ú', 'l') 1
# ('(', 'f', 'g') 1
# ('f', 'g', 'v') 1
# ('g', 'v', ')') 1
# ('t', 'v', '"') 1
# ('k', 'r', 'ä') 1
# ('r', 'ä', 'm') 1
# ('ä', 'm', 'e') 1
# ('p', 'u', 'x') 1
# ('x', 'e', 'u') 1
# ('a', 'e', 'o') 1
# ('u', 'a', 'q') 1
# ('a', 'q', ')') 1
# ('q', ')', ',') 1
# ('m', 't', 'e') 1
# ('í', 'o', ':') 1
# ('k', 's', '?') 1
# ('g', 'l', 'í') 1
# (' ', 'z', 'ü') 1
# ('z', 'ü', 'r') 1
# ('ü', 'r', 'c') 1
# ('z', 'ú', 'r') 1
# ('a', '-', 'w') 1
# ('t', 'f', 'a') 1
# ('é', 'e', 'l') 1
# ('u', 'c', 'á') 1
# ('á', 's', 'o') 1
# ('k', ' ', 'x') 1
# ('(', 'h', 'y') 1
# (' ', 'i', ')') 1
# ("'", 'a', 'd') 1
# ('m', 'á', "'") 1
# ('á', "'", ',') 1
# ('.', 'm', 'u') 1
# ('.', 'a', 'r') 1
# ('ú', 'b', 'r') 2
# ('(', 'a', 'g') 1
# ('k', 'h', 'u') 1
# ('m', 'b', 'h') 1
# ('d', 's', 'e') 2
# ('—', 'e', 'x') 1
# ('e', 'n', '—') 1
# ('ó', ' ', ':') 1
# ('v', 'e', 'p') 1
# ('h', 'ó', 's') 2
# ('d', '-', ' ') 1
# ('y', 'd', '’') 1
# ('d', '’', 's') 1
# ('y', 'a', '-') 1
# ('c', 'c', 'c') 1
# ('c', 'c', 'b') 1
# ('c', 'b', '.') 1
# ('j', 'é', 'n') 1
# ('r', 'g', 'g') 1
# ('i', 'f', 'd') 1
# ('i', 'm', ':') 1
# (' ', 'y', 'k') 1
# ('y', 'k', ',') 1
# ('d', 'f', 's') 1
# ('$', ' ', 'd') 1
# (' ', 'm', 'ä') 1
# ('m', 'ä', 'g') 1
# ('ä', 'g', 'o') 1
# ('¡', 'f', 'u') 1
# ('ç', 'a', '"') 1
# ('b', 'e', '”') 1
# ('”', ' ', '-') 1
# ('i', 'b', 'p') 1
# ('b', 'p', '.') 1
# ('p', '.', 'z') 1
# ('.', 'z', 'i') 1
# ('z', 'i', 'p') 1
# ('ó', 'n', 'b') 1
# ('n', 'b', 'i') 1
# ('f', 'e', 'g') 1
# ('l', 'é', 'x') 1
# ('i', 'x', ':') 1
# ('e', 't', '?') 1
# ('-', 'f', ',') 1
# ('-', 'c', 'c') 1
# (' ', 'é', 'd') 1
# ('é', 'd', 'g') 1
# ('l', 'í', '”') 1
# ('x', 'x', '"') 1
# ('x', '"', '.') 1
# (' ', 'l', 'r') 1
# ('c', 'á', '.') 2
# (' ', 'y', 'b') 1
# ('-', 'o', 'v') 1
# ('r', 'y', '-') 1
# ('y', '-', 'l') 1
# ('!', ' ', "'") 1
# ('w', 'm', 'e') 1
# ('(', 'n', 'e') 1
# ('a', 'k', 'p') 1
# ('k', 'p', ' ') 1
# ('t', 'v', 'i') 1
# ('e', ',', 's') 1
# (',', 's', 'a') 2
# ('s', 'i', 'z') 1
# ('s', 'é', '"') 1
# ('y', 'b', 'r') 1
# ('u', 'l', 'b') 1
# ('(', 'p', '.') 1
# ('.', ' ', ',') 1
# ('b', 'a', '…') 1
# ('p', 'p', 'p') 1
# ('t', 'a', '(') 3
# ('a', '(', 'p') 1
# ('z', ',', 'v') 1
# ('s', ',', 's') 1
# ('i', ',', 'u') 1
# (',', 'u', 'n') 1
# ('i', 'n', 'r') 1
# ('s', 'r', '-') 1
# ('b', 's', 'ó') 1
# ('l', "'", 's') 1
# ('(', "'", 'i') 1
# ("'", 'i', '’') 1
# ('u', "'", ')') 1
# ('"', 'i', '’') 1
# ('a', 'g', '”') 1
# ('h', 'ä', 'f') 1
# ('ä', 'f', 'f') 1
# ('h', 'n', 'l') 1
# ('u', 's', 'x') 1
# ('e', 'á', ' ') 1
# ("'", '¡', 'd') 1
# ('ñ', 'o', '”') 1
# ('l', 'k', 'r') 1
# (' ', 'r', 'b') 1
# ('r', 'b', 'd') 1
# ('b', 'd', ',') 1
# ('e', 'z', '…') 1
# ('z', '…', 'a') 1
# ('…', 'a', 's') 1
# ('n', 'n', 'á') 1
# ('-', ' ', ')') 1
# (':', ' ', '°') 1
# ('°', ' ', '/') 1
# ('a', ' ', '»') 1
# (' ', '»', 'f') 1
# ('»', 'f', 'r') 1
# ('í', 'o', ';') 1
# (' ', 'm', 'ª') 1
# ('m', 'ª', ' ') 1
# ('y', 'l', '.') 1
# ('l', 'í', '–') 1
# ('í', '–', 'a') 1
# ('–', 'a', 'r') 1
# ('“', ' ', 'a') 1
# ('á', 'd', 'a') 1
# ('¡', 'a', 'c') 1
# ('y', 'l', 'u') 1
# (',', ' ', '’') 1
# ('-', ')', ':') 1
# ('a', ')', ';') 1
# ('z', '.', '.') 1
# ('t', 'y', 'n') 1
# ('«', 'r', 'a') 1
# ('o', ' ', '»') 1
# ('í', ' ', "'") 1
# ('r', 'n', 'j') 1
# ('a', 'd', '–') 1
# ('d', '–', ' ') 1
# ('n', 't', 'b') 1
# ('t', 'b', 'l') 1
# ('c', 'h', '-') 1
# ('h', '-', 'r') 1
# ('-', 'r', ' ') 1
# (' ', 'q', 'w') 1
# ('q', 'w', 'e') 1
# ('i', 'ñ', 'i') 1
# ('k', 'k', ' ') 1
# ('r', ' ', '—') 1
# ('—', ' ', 'o') 1

# %% [markdown]
# ## Eliminació de trigrames que apareixin menys de 5 vegades

# %%
trigrames_deu_trn.apply_freq_filter(5)

trigrames_eng_trn.apply_freq_filter(5)

trigrames_fra_trn.apply_freq_filter(5)

trigrames_ita_trn.apply_freq_filter(5)

trigrames_nld_trn.apply_freq_filter(5)

trigrames_spa_trn.apply_freq_filter(5)

# %%
print("Trigramas després del filtre:")
for trigram, freq in trigrames_spa_trn.ngram_fd.items():
    if freq<5:
        print(trigram, freq)
# Out:
# Trigramas després del filtre:

# %% [markdown]
# ## Creació del model

# %% [markdown]
# <span style="color:lightgreen"> Creem un diccionari per a cada idioma per emmagatzemar les ocurrències de cada trigrama en aquest idioma. Per dur a terme la identificació dels idiomes, desenvolupem el model utilitzant la tècnica de suavitzat 'LID'. La massa de probabilitat reservada que seleccionem en cas de trobar-nos amb un trigrama no observat és de 0.5. Utilitzem el nombre de unigrames diferents que apareixen en cada corpus d'entrenament com a valor de 'B' per a cada idioma en la funció del model que calcula la probabilitat. </span>

# %% [markdown]
# Maximum likelihood estimator model

# %%
y = 0.5 # massa de probabilitat reservada

### Diccionari alemany

diccionari_deu = {}

Nt_deu = sum(ej[1] for ej in trigrames_deu_trn.ngram_fd.items()) # num. d'ocurrències d'unigrames en el corpus d'entrenament
B_deu = len(trigrames_deu_trn.ngram_fd.items()) # unigrames potencialment observables

for ej in trigrames_deu_trn.ngram_fd.items():
    ct = ej[1] # num. d'ocurrències de ej en el corpus d'entrenament
    diccionari_deu[ej[0]] = ct


### Diccionari anglès

diccionari_eng = {}

Nt_eng = sum(ej[1] for ej in trigrames_eng_trn.ngram_fd.items()) # num. d'ocurrències d'unigrames en el corpus d'entrenament
B_eng = len(trigrames_eng_trn.ngram_fd.items()) # unigrames potencialment observables

for ej in trigrames_eng_trn.ngram_fd.items():
    ct = ej[1] # num. d'ocurrències de ej en el corpus d'entrenament
    diccionari_eng[ej[0]] = ct


### Diccionari francès

diccionari_fra = {}

Nt_fra = sum(ej[1] for ej in trigrames_fra_trn.ngram_fd.items()) # num. d'ocurrències d'unigrames en el corpus d'entrenament
B_fra = len(trigrames_fra_trn.ngram_fd.items()) # unigrames potencialment observables

for ej in trigrames_fra_trn.ngram_fd.items():
    ct = ej[1] # num. d'ocurrències de ej en el corpus d'entrenament
    diccionari_fra[ej[0]] = ct


### Diccionari italià

diccionari_ita = {}

Nt_ita = sum(ej[1] for ej in trigrames_ita_trn.ngram_fd.items()) # num. d'ocurrències d'unigrames en el corpus d'entrenament
B_ita = len(trigrames_ita_trn.ngram_fd.items()) # unigrames potencialment observables

for ej in trigrames_ita_trn.ngram_fd.items():
    ct = ej[1] # num. d'ocurrències de ej en el corpus d'entrenament
    diccionari_ita[ej[0]] = ct
    

### Diccionari neerlandès

diccionari_nld = {}

Nt_nld = sum(ej[1] for ej in trigrames_nld_trn.ngram_fd.items()) # num. d'ocurrències d'unigrames en el corpus d'entrenament
B_nld = len(trigrames_nld_trn.ngram_fd.items()) # unigrames potencialment observables

for ej in trigrames_nld_trn.ngram_fd.items():
    ct = ej[1] # num. d'ocurrències de ej en el corpus d'entrenament
    diccionari_nld[ej[0]] = ct
    

### Diccionari espanyol

diccionari_spa = {}

Nt_spa = sum(ej[1] for ej in trigrames_spa_trn.ngram_fd.items()) # num. d'ocurrències d'unigrames en el corpus d'entrenament
B_spa = len(trigrames_spa_trn.ngram_fd.items()) # unigrames potencialment observables

for ej in trigrames_spa_trn.ngram_fd.items():
    ct = ej[1] # num. d'ocurrències de ej en el corpus d'entrenament
    diccionari_spa[ej[0]] = ct

# %% [markdown]
# <span style="color:lightgreen"> Definim la funció "lid" per a calcular la llei de Lidston. En aquest context, calcularem el logaritme neperià, ja que necessitarem sumar diverses probabilitats per a esbrinar la llengua de la frase la qual estem analitzant. </span>

# %%
import math

def lid(ct,N,B):
    """
    Funció que calcula el logaritme de la probabilitat del trigrama amb la tècnica 'LID'
    """
        
    i = math.log((ct+y)/(N + y*B))
    
    return i

# %% [markdown]
# <span style="color:lightgreen"> Creem la funció que calcula la probabilitat de cada frase que passem del corpus del test aplicant la tècnica de smoothing LID. </span>

# %%
idiomes = ['deu', 'eng', 'fra', 'ita', 'nld', 'spa']

diccionari_idiomes = {
    'deu': (diccionari_deu, Nt_deu, B_deu),
    'eng': (diccionari_eng, Nt_eng, B_eng),
    'fra': (diccionari_fra, Nt_fra, B_fra),
    'ita': (diccionari_ita, Nt_ita, B_ita),
    'nld': (diccionari_nld, Nt_nld, B_nld),
    'spa': (diccionari_spa, Nt_spa, B_spa)
}

def model_LID(text_test):
    """Aquesta funció retorna la probabilitat del text per a cada idioma"""

    # Inicialitzem un diccionari per a comptar les prediccions de cada idioma i el total de prediccions
    count_predicciones = {idioma: 0 for idioma in idiomes}

    frases = text_test.split("  ")
    
    probabilitat = {}
    
    for frase in frases:
        
        trigrames = TrigramCollocationFinder.from_words(frase)
    
        for lng, (diccionari, Nt, B) in diccionari_idiomes.items():
            
            total = 0
            
            for ej in trigrames.ngram_fd.items():
                
                if ej[0] in diccionari:
                    total += lid(diccionari[ej[0]],Nt,B) # calculem el productori de les probabilitats
                else:
                    total += lid(0,Nt,B)
                    
            probabilitat[lng] = total
        
        # Obtenim l'idioma amb major probabilitat
        idioma_predit = max(probabilitat, key=probabilitat.get)
        
        # Actualitzem els contadors de prediccions
        count_predicciones[idioma_predit] += 1

    # Retornem la precisió i el diccionari de prediccions
    return count_predicciones

# %% [markdown]
# ## Identificació Idiomes

# %% [markdown]
# <span style="color:lightgreen"> Fem la identificació dels idiomes i creem la matriu que utilitzarem per avaluar el model. </span>

# %%
# identificació idioma
texts = [text_processat_deu_tst, text_processat_eng_tst, text_processat_fra_tst, text_processat_ita_tst, text_processat_nld_tst, text_processat_spa_tst]

pred_values = []
for text in (texts):
    matriz_lang = model_LID(text)
    print(matriz_lang)
    pred_values.append([matriz_lang[idioma] for idioma in matriz_lang])
# Out:
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}

# %% [markdown]
# ## Avaluació rendiment

# %% [markdown]
# <span style="color:lightgreen"> Creem la matriu de confussió i calculem la accuracy del model. </span>

# %%
pred_values
# Out:
# [[10592, 26, 10, 24, 22, 9],
#  [37, 10195, 22, 5, 14, 5],
#  [9, 10, 10185, 3, 5, 6],
#  [21, 21, 7, 10349, 12, 10],
#  [37, 37, 8, 8, 10330, 4],
#  [163, 17, 5, 18, 10, 10252]]

# %%
import matplotlib.pyplot as plt
import numpy as np

matriz = np.array(pred_values)

# Crear el gràfic de 'pred_values'
plt.figure(figsize=(10, 6))

# Dibuixar la matriu com una imatge
plt.imshow(matriz, cmap='Blues_r', interpolation='nearest')

# Afegir linies entre els quadrats
for i in range(matriz.shape[0] + 1):
    plt.axhline(i - 0.5, color='black', linewidth=0.5)

for j in range(matriz.shape[1] + 1):
    plt.axvline(j - 0.5, color='black', linewidth=0.5)

# Afegir etiquetes amb els números de la matriu pred_values
for i in range(matriz.shape[0]):
    for j in range(matriz.shape[1]):
        plt.text(j, i, str(matriz[i, j]), ha='center', va='center', color='black')

# Ajustar l'aparença del gràfic
plt.colorbar(label='Valor')
plt.title('Matriu de confusió')
plt.xlabel('Predicció')
plt.ylabel('Originals')

# Afegir les etiquetes d'idiomes per a les files i columnes
plt.xticks(range(len(idiomes)), idiomes)
plt.yticks(range(len(idiomes)), idiomes)

plt.show()

# %% [markdown]
# <span style="color:lightgreen"> Es pot observar que la majoria dels valors es concentren a la diagonal, indicant que el model ha aconseguit un bon rendiment. No obstant això, en el cas de la predicció de textos escrits en castellà, es pot notar un nombre relativament elevat de prediccions incorrectes associades a l'idioma alemany, en comparació amb altres idiomes. Malgrat això, aquest nombre d'errors no supera les 200 frases incorrectament predites. </span>

# %% [markdown]
# ### Accuracy

# %% [markdown]
# Indivdual class Accuracy = TP of that class/total instances in that class

# %%
def evaluate_model(matriu):
    """
    Funció que retorna una matriu de confussió i els True Positives, False Positives, True Negatives i els 
    False Negatives de cada classe de la matriu 
    """
    
    predicted_idiomes = [f"Predicted_{idioma}" for idioma in idiomes]
    
    # Imprimim el títol
    print("{:^20}".format("Confusion Matrix Output"))
    
    # Imprimim els noms dels idiomes com a títols de les columnes
    header_format = "{:<20} |" + "| ".join(["{:<15}" for _ in range(len(idiomes))])
    print(header_format.format(" ", *predicted_idiomes))
    
    # Imprimim línia horitzontal a sota dels noms de les columnes
    print("{:<20} |".format("_" * 20), end="")
    for _ in range(len(idiomes)):
        print("{:<15}| ".format("_" * 15), end="")
    print()
    
    # Imprimim cada fila de la matriu amb el nom de l'idioma corresponent
    for i in range(len(idiomes)):
        row_values = [str(value) for value in matriu[i]]
        print("{:<20} |".format(f'Actual_{idiomes[i]}'), end="")
        for value in row_values:
            print("{:<15}| ".format(value), end="")
        print()
        
        # Imprimim línia horitzontal després de cada fila
        print("{:<20} |".format("_" * 20), end="")
        for _ in range(len(idiomes)):
            print("{:<15}| ".format("_" * 15), end="")
        print()


    # Imprimim encabezado
    print("\n")
    print("{:^20}".format("Evaluation"))
    print("{:<20} {:<15} {:<15} {:<15} {:<15} ".format(" ", "TruePositive", "FalsePositive", "FalseNegative", "TrueNegative"))
    print("{:<20} {:^15} {:^15} {:^15} {:^15} ".format("", "_"*14 + " ", "_"*14 + " ", "_"*14 + " ", "_"*13 + " "))

    # Imprimim cada fila de la matriu amb el nom de l'idioma corresponent
    for i in range(len(idiomes)):
        row_values = []
        # Calculem True Positives, False Positives, False Negatives y True Negatives
        TP = matriu[i][i]
        FP = sum(matriu[j][i] for j in range(len(idiomes)) if j != i)
        FN = sum(matriu[i][j] for j in range(len(idiomes)) if j != i)
        TN = sum(sum(matriu[j]) for j in range(len(idiomes))) - TP - FP - FN
        
        # Agreguem els valors a la llista row_values
        row_values.extend([TP, FP, FN, TN])
        # Imprimim cada fila de la matriu amb el nom de l'idioma corresponent

        print("{:<20}".format(f'Actual_{idiomes[i]}'), end="")
        for value in row_values:
            print("{:^15}".format(value), end="")
        print("\n{:^15} {:^15} {:^15} {:^15} {:^15} ".format("", "", "", "", ""))

evaluate_model(pred_values)
# Out:
# Confusion Matrix Output
#                      |Predicted_deu  | Predicted_eng  | Predicted_fra  | Predicted_ita  | Predicted_nld  | Predicted_spa
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
# Actual_deu           |10592          | 26             | 10             | 24             | 22             | 9              |
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
# Actual_eng           |37             | 10195          | 22             | 5              | 14             | 5              |
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
# Actual_fra           |9              | 10             | 10185          | 3              | 5              | 6              |
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
# Actual_ita           |21             | 21             | 7              | 10349          | 12             | 10             |
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
# Actual_nld           |37             | 37             | 8              | 8              | 10330          | 4              |
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
# Actual_spa           |163            | 17             | 5              | 18             | 10             | 10252          |
# ____________________ |_______________| _______________| _______________| _______________| _______________| _______________|
#
#
#      Evaluation
#                      TruePositive    FalsePositive   FalseNegative   TrueNegative
#                      ______________  ______________  ______________  _____________
# Actual_deu               10592           267            91            51538
#
# Actual_eng               10195           111            83            52099
#
# Actual_fra               10185           52             33            52218
#
# Actual_ita               10349           58             71            52010
#
# Actual_nld               10330           63             94            52001
#
# Actual_spa               10252           34             213           51989

# %%
import pandas as pd

def calculate_metrics(matriu):
    """ 
    Retorna un DataFrame amb la precisió de cada classe de la matriu calculada
    """
    dic_accuracy = {}

    for i, lng in enumerate(idiomes):
        
        # Calculem True Positives, False Positives, False Negatives y True Negatives
        TP = matriu[i][i]
        FP = sum(matriu[j][i] for j in range(len(idiomes)) if j != i)
        FN = sum(matriu[i][j] for j in range(len(idiomes)) if j != i)
        TN = sum(sum(matriu[j]) for j in range(len(idiomes))) - TP - FP - FN    
        
        # Calculem la precisió i l'emmagatzamem en el diccionari
        dic_accuracy[lng] = TP / (TP + FN)
        
    # Convertim el diccionari en un DataFrame
    df_accuracy = pd.DataFrame(dic_accuracy.items(), columns=['Idioma', 'Accuracy'])
        
    return df_accuracy
            
df_accuracy = calculate_metrics(pred_values)
df_accuracy
# Out:
#   Idioma  Accuracy
# 0    deu  0.991482
# 1    eng  0.991924
# 2    fra  0.996770
# 3    ita  0.993186
# 4    nld  0.990982
# 5    spa  0.979646

# %% [markdown]
# ## CONCLUSIONS FINALS

# %% [markdown]
# <span style="color:lightgreen"> Els resultats assenyalen que el nostre model és capaç de predir amb alta precisió els idiomes en què ha estat entrenat. L'accuracy pels diferents llanguatges revela una precisió lleugerament inferior en la predicció dels textos en espanyol en comparació amb altres idiomes, indicant-nos que hi ha algunes diferències que podrien afectar la capacitat de generalització del model. Una possible solució per millorar aquesta precisió podria ser l'augment de la grandària de la base de dades, és a dir, corpus amb més textos, o bé l'ús d'una funció de 'smoothing' més precisa. També considerem que podríem millorar les prediccions trobant uns hiperparàmetres 'lambda' i 'B' millors en el model basant-nos en cada corpus d'entrenament, per exemple, podríem fer una validació creuada en cada conjunt d'entrenament. Tot i així, el nostre model, com ja hem esmentat, és prou competitiu. </span>

# %% [markdown]
# # EXTRA

# %% [markdown]
# <span style="color:lightgreen"> En aquesta secció, intentarem trobar els valors òptims de 'y' i 'B', ja que anteriorment hem utilitzat aproximacions. En les llistes 'range_y' i 'range_B', es poden veure els valors que provarem per intentar trobar el model amb la millor precisió. </span>

# %% [markdown]
# #### Prova 1

# %%
import pandas as pd

# Definim rangs per a 'y' i 'B'
range_y = [0.1, 0.25, 0.5, 0.75, 1.0]  
range_B = [10000, 12500, 15000, 17500, 20000, 22500, 25000, 27500, 30000] 

best_mean_accuracy = 0
best_y = None
best_B = None

# Iterem sobre totes les combinacions de 'y' i 'B'
for lbd in range_y:
    
    y = lbd
    
    for b in range_B:
        # Modifiquem el diccionari d'idiomes amb els nous valors de 'y' i 'B'
        diccionari_idiomes_optimized = {
            'deu': (diccionari_deu, Nt_deu, b),
            'eng': (diccionari_eng, Nt_eng, b),
            'fra': (diccionari_fra, Nt_fra, b),
            'ita': (diccionari_ita, Nt_ita, b),
            'nld': (diccionari_nld, Nt_nld, b),
            'spa': (diccionari_spa, Nt_spa, b)
        }

        all_accuracies = []  # Llista per a emmagatzemar totes les accuracies
        pred_values = []
        for text in texts:
            matriz_lang = model_LID(text)
            pred_values.append([matriz_lang[idioma] for idioma in matriz_lang])
        
        accuracy_df = calculate_metrics(pred_values)
        all_accuracies.append(accuracy_df)

        # Calculem la mitjana de les accuracies per aquesta combinació de 'y' i 'B'
        mean_accuracy_df = pd.concat(all_accuracies).groupby('Idioma').mean().reset_index()
        mean_accuracy = mean_accuracy_df['Accuracy'].mean()

        # Actualitzem la millor mitjana de precisió i els millors valors de 'y' y 'B' si és necessari
        if mean_accuracy > best_mean_accuracy:
            best_mean_accuracy = mean_accuracy
            best_y = y
            best_B = b

print("Mejor media de precisión:", best_mean_accuracy)
print("Mejor y:", best_y)
print("Mejor B:", best_B)

# %% [markdown]
# <span style="color:lightgreen"> Un cop realitzat l'experiment hem determinat que el valor òptim de 'y' és 0.5 i el valor de 'B' és 10000. Seguidament, hem dut a terme més proves variant el valor de 'B' per 'B' més petites. Després de diverses proves, hem comprovat que l'accuracy es manté constant amb un valor de 'y' igual a 0.5, independentment del valor de 'B'. </span>

# %% [markdown]
# #### Prova 2

# %%
import pandas as pd

# Definim rangs per a 'y' i 'B'
range_y = [0.1, 0.25, 0.5, 0.75, 1.0]  
range_B = [5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000] 

best_mean_accuracy = 0
best_y = None
best_B = None

# Iterem sobre totes les combinacions de 'y' i 'B'
for lbd in range_y:
    
    y = lbd
    
    for b in range_B:
        # Modifiquem el diccionari d'idiomes amb els nous valors de 'y' i 'B'
        diccionari_idiomes_optimized = {
            'deu': (diccionari_deu, Nt_deu, b),
            'eng': (diccionari_eng, Nt_eng, b),
            'fra': (diccionari_fra, Nt_fra, b),
            'ita': (diccionari_ita, Nt_ita, b),
            'nld': (diccionari_nld, Nt_nld, b),
            'spa': (diccionari_spa, Nt_spa, b)
        }

        all_accuracies = []  # Llista per a emmagatzemar totes les accuracies
        pred_values = []
        for text in texts:
            matriz_lang = model_LID(text)
            pred_values.append([matriz_lang[idioma] for idioma in matriz_lang])
        
        accuracy_df = calculate_metrics(pred_values)
        all_accuracies.append(accuracy_df)

        # Calculem la mitjana de les accuracies per aquesta combinació de 'y' i 'B'
        mean_accuracy_df = pd.concat(all_accuracies).groupby('Idioma').mean().reset_index()
        mean_accuracy = mean_accuracy_df['Accuracy'].mean()

        # Actualitzem la millor mitjana de precisió i els millors valors de 'y' y 'B' si és necessari
        if mean_accuracy > best_mean_accuracy:
            best_mean_accuracy = mean_accuracy
            best_y = y
            best_B = b

print("Mejor media de precisión:", best_mean_accuracy)
print("Mejor y:", best_y)
print("Mejor B:", best_B)
# Out:
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# Mejor media de precisión: 0.9907290602951758
# Mejor y: 0.5
# Mejor B: 5000

# %% [markdown]
# #### Prova 3

# %%
import pandas as pd

# Definim rangs per a 'y' i 'B'
range_y = [0.1, 0.25, 0.5, 0.75, 1.0]  
range_B = [1000, 2000, 3000, 4000, 5000]  

best_mean_accuracy = 0
best_y = None
best_B = None

# Iterem sobre totes les combinacions de 'y' i 'B'
for lbd in range_y:
    
    y = lbd
    
    for b in range_B:
        # Modifiquem el diccionari d'idiomes amb els nous valors de 'y' i 'B'
        diccionari_idiomes_optimized = {
            'deu': (diccionari_deu, Nt_deu, b),
            'eng': (diccionari_eng, Nt_eng, b),
            'fra': (diccionari_fra, Nt_fra, b),
            'ita': (diccionari_ita, Nt_ita, b),
            'nld': (diccionari_nld, Nt_nld, b),
            'spa': (diccionari_spa, Nt_spa, b)
        }

        all_accuracies = []  # Llista per a emmagatzemar totes les accuracies
        pred_values = []
        for text in texts:
            matriz_lang = model_LID(text)
            pred_values.append([matriz_lang[idioma] for idioma in matriz_lang])
        
        accuracy_df = calculate_metrics(pred_values)
        all_accuracies.append(accuracy_df)

        # Calculem la mitjana de les accuracies per aquesta combinació de 'y' i 'B'
        mean_accuracy_df = pd.concat(all_accuracies).groupby('Idioma').mean().reset_index()
        mean_accuracy = mean_accuracy_df['Accuracy'].mean()

        # Actualitzem la millor mitjana de precisió i els millors valors de 'y' y 'B' si és necessari
        if mean_accuracy > best_mean_accuracy:
            best_mean_accuracy = mean_accuracy
            best_y = y
            best_B = b

print("Mejor media de precisión:", best_mean_accuracy)
print("Mejor y:", best_y)
print("Mejor B:", best_B)
# Out:
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 24, 'nld': 22, 'spa': 9}
# {'deu': 37, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 14, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10349, 'nld': 12, 'spa': 10}
# {'deu': 37, 'eng': 37, 'fra': 8, 'ita': 8, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 17, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10252}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 26, 'fra': 10, 'ita': 25, 'nld': 21, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 9, 'eng': 10, 'fra': 10185, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 22, 'fra': 6, 'ita': 10351, 'nld': 10, 'spa': 10}
# {'deu': 36, 'eng': 39, 'fra': 8, 'ita': 7, 'nld': 10330, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 18, 'nld': 10, 'spa': 10251}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10195, 'fra': 22, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 20, 'fra': 6, 'ita': 10353, 'nld': 10, 'spa': 10}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10592, 'eng': 25, 'fra': 10, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 5, 'nld': 13, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 35, 'eng': 39, 'fra': 6, 'ita': 7, 'nld': 10333, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# {'deu': 10591, 'eng': 25, 'fra': 11, 'ita': 25, 'nld': 22, 'spa': 9}
# {'deu': 38, 'eng': 10194, 'fra': 23, 'ita': 4, 'nld': 14, 'spa': 5}
# {'deu': 10, 'eng': 10, 'fra': 10184, 'ita': 3, 'nld': 5, 'spa': 6}
# {'deu': 21, 'eng': 21, 'fra': 7, 'ita': 10350, 'nld': 10, 'spa': 11}
# {'deu': 36, 'eng': 39, 'fra': 7, 'ita': 7, 'nld': 10331, 'spa': 4}
# {'deu': 163, 'eng': 18, 'fra': 5, 'ita': 19, 'nld': 10, 'spa': 10250}
# Mejor media de precisión: 0.9907290602951758
# Mejor y: 0.5
# Mejor B: 1000
